# %% [markdown]
# # Load Layer outputs

# %%
nn = 'DNN'

import pickle
with open('results/' + nn + '_layer_outputs.dat','rb') as f:
    layer_outs,layer_outs_test= pickle.load(f)
f.close()

# %% [markdown]
# # Load recording and test data

# %%
import numpy as np
from keras.datasets import mnist
from scipy.misc import imresize

(Xtrain, Ytrain), (Xtest, Ytest) = mnist.load_data()

(ntrain, xdim, ydim) = Xtrain.shape
ntest = Xtest.shape[0]

# Recording data
X_pr = Xtrain[30000:60000, :, :]
Y_pr = Ytrain[30000:60000]


# downsample
factor = 1
if factor<1:
    Xtest_down = np.ones((Xtest.shape[0], int(xdim*factor), int(ydim*factor)))
    for i in range(Xtest.shape[0]):
        Xtest_down[i,:,:] = imresize(Xtest[i,:,:], factor)

    X_pr_down = np.ones((X_pr.shape[0], int(xdim*factor), int(ydim*factor)))
    for i in range(X_pr.shape[0]):
        X_pr_down[i,:,:] = imresize(X_pr[i,:,:], factor)
else:
    Xtest_down = Xtest
    X_pr_down = X_pr
    
# VECTORIZE IMAGES
Xtest_down = Xtest_down.reshape(ntest, int(xdim*factor)**2).astype('float32') / 255
X_pr_down = X_pr_down.reshape(X_pr_down.shape[0], int(xdim*factor)**2).astype('float32') / 255
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run XGBOOST

# %%
from copy import copy, deepcopy
from RE_PartialRecData import RE_PartialRecData
from RE_PartialRecData2 import RE_PartialRecData2
import os
import xgboost as xgb
import sklearn
from xgboost.sklearn import XGBClassifier
import pickle

params = {}
# use softmax multi-class classification 'multi:softmax'
# use linear regression 'reg:linear'
params['objective'] = 'reg:linear'
# scale weight of positive examples
params['eta'] = 0.5               # Makes the model more robust by shrinking the weights on each step (0.01-0.2)
params['max_depth'] = 6           # Used to control over-fitting as higher depth will allow model to learn relations 
                                  # very specific to a particular sample. (3-10)
params['silent'] = 1
params['nthread'] = 4
# params['num_class'] = 10
num_round = 5

# how many recordings?
recordings = [4**x for x in range(4)]
nRecordings = len(recordings)
# how many neurons from the firs hidden layer?
subnetSize = [2**x for x in range(8)]
nSubnetSize = len(subnetSize)
# which layers?
iLayer = 5
# how many samples per recording?
nSamples = np.divide(int(X_pr_down.shape[0]/nRecordings),subnetSize)*100
# how many iterations
nIterations = 5

# baseline prediction error
#bl = np.std(layer_outs_test[oLayer]-np.mean(layer_outs_test[oLayer]));

oLayer = len(layer_outs)-1  # index of output layer
nOutNeurons = layer_outs[oLayer].shape[1]
rmses = np.zeros([nOutNeurons, nIterations, nSubnetSize, nRecordings])

for nr in range(nRecordings):
    # how many samples per recording?
    nSamples = np.divide(int(X_pr_down.shape[0]/recordings[nr]),subnetSize)*100
    for ss in range(nSubnetSize):
        print(subnetSize[ss])
        for it in range(nIterations):
            # copy data
            layer_outputs = deepcopy(layer_outs)
            # subsample
            X_subsample, Y_subsample = RE_PartialRecData2(layer_outputs[iLayer], layer_outputs[oLayer], 
                                                          subnetSize[ss], recordings[nr],nSamples[ss])
    #        print('# nan values: ',np.count_nonzero(np.isnan(X_subsample)))
            # prepare data for xgboost
            for iN in range(nOutNeurons):
                #print('#neuron, #iteratin, subnetsize: ', iN,it,subnetSize[ss])
                xg_train  = xgb.DMatrix(X_subsample, label=Y_subsample[:, iN])
                xg_test   = xgb.DMatrix(layer_outs_test[iLayer], label=layer_outs_test[oLayer][:,iN])
                watchlist = [(xg_train, 'train'), (xg_test, 'test')]
                # train XGboost
                bst = xgb.train(params, xg_train, num_round, watchlist, verbose_eval=False)
                # get predictions
                pred = bst.predict(xg_test)
                rmses[iN,it,ss,nr] = np.sqrt(np.mean(np.square([(pred[i] - layer_outs_test[oLayer][:,iN][i]) 
                                             for i in range(len(layer_outs_test[oLayer][:,1]))])))
            print ('predicting, RMSE=%f' %np.mean(rmses[:, it, ss, nr]))
# Out:
# 1
# predicting, RMSE=0.298407
# predicting, RMSE=0.263465
# predicting, RMSE=0.250618
# predicting, RMSE=0.273345
# predicting, RMSE=0.243450
# 2
# predicting, RMSE=0.275851
# predicting, RMSE=0.253425
# predicting, RMSE=0.272750
# predicting, RMSE=0.263556
# predicting, RMSE=0.178749
# 4
# predicting, RMSE=0.242294
# predicting, RMSE=0.200950
# predicting, RMSE=0.272885
# predicting, RMSE=0.152846
# predicting, RMSE=0.215346
# 8
# predicting, RMSE=0.204238
# predicting, RMSE=0.111810
# predicting, RMSE=0.216573
# predicting, RMSE=0.246770
# predicting, RMSE=0.083473
# 16
# predicting, RMSE=0.189282
# predicting, RMSE=0.144055
# predicting, RMSE=0.087912
# predicting, RMSE=0.188854
# predicting, RMSE=0.124294
# 32
# predicting, RMSE=0.065358
# predicting, RMSE=0.038723
# predicting, RMSE=0.078027
# predicting, RMSE=0.037197
# predicting, RMSE=0.035171
# 64
# predicting, RMSE=0.023683
# predicting, RMSE=0.021828
# predicting, RMSE=0.022953
# predicting, RMSE=0.025305
# predicting, RMSE=0.023757
# 128
# predicting, RMSE=0.021351
# predicting, RMSE=0.021895
# predicting, RMSE=0.021370
# predicting, RMSE=0.021665
# predicting, RMSE=0.021884
# 1
# predicting, RMSE=0.297203
# predicting, RMSE=0.259449
# predicting, RMSE=0.296674
# predicting, RMSE=0.240381
# predicting, RMSE=0.280509
# 2
# predicting, RMSE=0.213114
# predicting, RMSE=0.221840
# predicting, RMSE=0.203510
# predicting, RMSE=0.218478
# predicting, RMSE=0.172497
# 4
# predicting, RMSE=0.212005
# predicting, RMSE=0.173299
# predicting, RMSE=0.188286
# predicting, RMSE=0.170692
# predicting, RMSE=0.178479
# 8
# predicting, RMSE=0.158864
# predicting, RMSE=0.160708
# predicting, RMSE=0.125350
# predicting, RMSE=0.176252
# predicting, RMSE=0.150402
# 16
# predicting, RMSE=0.160063
# predicting, RMSE=0.135471
# predicting, RMSE=0.075627
# predicting, RMSE=0.122809
# predicting, RMSE=0.110087
# 32
# predicting, RMSE=0.065174
# predicting, RMSE=0.051056
# predicting, RMSE=0.074536
# predicting, RMSE=0.064673
# predicting, RMSE=0.038754
# 64
# predicting, RMSE=0.030347
# predicting, RMSE=0.027967
# predicting, RMSE=0.036427
# predicting, RMSE=0.027467
# predicting, RMSE=0.027483
# 128
# predicting, RMSE=0.022038
# predicting, RMSE=0.020919
# predicting, RMSE=0.022536
# predicting, RMSE=0.021291
# predicting, RMSE=0.021632
# 1
# predicting, RMSE=0.189715
# predicting, RMSE=0.179261
# predicting, RMSE=0.160047
# predicting, RMSE=0.150599
# predicting, RMSE=0.235173
# 2
# predicting, RMSE=0.180523
# predicting, RMSE=0.155040
# predicting, RMSE=0.155877
# predicting, RMSE=0.144314
# predicting, RMSE=0.155813
# 4
# predicting, RMSE=0.148190
# predicting, RMSE=0.159653
# predicting, RMSE=0.144059
# predicting, RMSE=0.167465
# predicting, RMSE=0.190160
# 8
# predicting, RMSE=0.180925
# predicting, RMSE=0.156153
# predicting, RMSE=0.207557
# predicting, RMSE=0.172861
# predicting, RMSE=0.175543
# 16
# predicting, RMSE=0.131032
# predicting, RMSE=0.177855
# predicting, RMSE=0.163080
# predicting, RMSE=0.162859
# predicting, RMSE=0.171984
# 32
# predicting, RMSE=0.106632
# predicting, RMSE=0.099908
# predicting, RMSE=0.125596
# predicting, RMSE=0.102224
# predicting, RMSE=0.105583
# 64
# predicting, RMSE=0.037625
# predicting, RMSE=0.046520
# predicting, RMSE=0.045443
# predicting, RMSE=0.041997
# predicting, RMSE=0.045960
# 128
# predicting, RMSE=0.021363
# predicting, RMSE=0.021978
# predicting, RMSE=0.021013
# predicting, RMSE=0.021522
# predicting, RMSE=0.022080
# 1
# predicting, RMSE=0.181061
# predicting, RMSE=0.193251
# predicting, RMSE=0.205919
# predicting, RMSE=0.188503
# predicting, RMSE=0.193286
# 2
# predicting, RMSE=0.191084
# predicting, RMSE=0.191397
# predicting, RMSE=0.186450
# predicting, RMSE=0.178988
# predicting, RMSE=0.165834
# 4
# predicting, RMSE=0.201172
# predicting, RMSE=0.180590
# predicting, RMSE=0.166227
# predicting, RMSE=0.169135
# predicting, RMSE=0.166137
# 8
# predicting, RMSE=0.200827
# predicting, RMSE=0.232758
# predicting, RMSE=0.154380
# predicting, RMSE=0.209941
# predicting, RMSE=0.169528
# 16
# predicting, RMSE=0.176500
# predicting, RMSE=0.183474
# predicting, RMSE=0.195110
# predicting, RMSE=0.186994
# predicting, RMSE=0.207319
# 32
# predicting, RMSE=0.139488
# predicting, RMSE=0.140817
# predicting, RMSE=0.141963
# predicting, RMSE=0.162131
# predicting, RMSE=0.124571
# 64
# predicting, RMSE=0.038697
# predicting, RMSE=0.041166
# predicting, RMSE=0.043454
# predicting, RMSE=0.042377
# predicting, RMSE=0.037903
# 128
# predicting, RMSE=0.023174
# predicting, RMSE=0.021369
# predicting, RMSE=0.022267
# predicting, RMSE=0.022712
# predicting, RMSE=0.021751

# %% [markdown]
# # Save RMSE's

# %%
nn = 'DNN'
fName = 'results/XGB_RMSES_Layer' + str(iLayer) + 'diff_nRec' + nn + '.dat'
# save the rmse's
with open(fName,'wb') as f:
    pickle.dump(rmses, f)
f.close()

# %% [markdown]
# # Plot RMSE's

# %%
import matplotlib.pyplot as pl
# %matplotlib inline
import numpy as np

RMSE = np.mean(np.mean(rmses, axis=0), axis=0)
RMSE = np.transpose(RMSE)

fig = pl.figure(figsize=(10,6))
ax = fig.add_subplot(111)
cax = ax.pcolor(RMSE)
ax.set_xlabel('# observed neurons (out of 128)', fontsize=18)
ax.set_ylabel('# partial recordings', fontsize=18)
ax.set_xticks(np.arange(0.5,nSubnetSize))
ax.set_xticklabels(subnetSize)
ax.set_yticks(np.arange(0.5,nRecordings))
ax.set_yticklabels(recordings)
ax.set_title('RMSE (Layer '+str(iLayer)+')', fontsize=24)
fig.colorbar(cax)
pl.draw()
figName = 'figures/1XGB_RMSES_Layer' + str(iLayer) + '_diff_nRec_' + nn
pl.savefig(figName +'.pdf', format='pdf')
pl.savefig(figName +'.eps', format='eps', dpi=1000)

# %% [markdown]
# # Plot RMSE's vs. No. observed neurons per recordings

# %%
# import matplotlib.pyplot as pl
# %matplotlib inline
# import numpy as np

# fig=pl.figure(figsize=(10,6))
# ax1 = fig.add_subplot(111)
# ax1.set_xlim([0, 128])
# ax2 = ax1.twiny()

# x = subnetSize;
# y = np.mean(np.median(rmses, axis=1), axis=0)
# error = np.std(np.mean(rmses, axis=1), axis=0)
# bl = np.std(layer_outs_test[oLayer]-np.mean(layer_outs_test[oLayer]));

# pl.semilogx(x, y, 'k-')
# # horiz_line_data = np.array([bl for i in xrange(len(x))])
# # pl.plot(x, horiz_line_data, 'k--') 
# pl.fill_between(x, y-error, y+error, alpha=0.2, facecolor='#808080')

# ax1.set_xlabel('# observed neurons on Layer' + str(iLayer) + '(out of 128)', fontsize=18)
# ax2.set_xlabel('Samples per recording',  fontsize=16)

# new_tick_locations = subnetSize
# ax1.set_xlim(ax1.get_xlim())
# ax1.set_xticks(new_tick_locations)
# ax1.set_xticklabels(new_tick_locations)

# new_tick_locations = subnetSize
# ax2.set_xlim(ax1.get_xlim())
# ax2.set_xticks(new_tick_locations)
# ax2.set_xticklabels(nSamples)


# # ax2.set_xticks(nSamples)
# # ax2.set_xticklabels(nSamples[range(0, 5, 20)])
# ax1.set_ylabel('RMSE', fontsize=18)
# ax1.set_ylim([0, .50])

# # pl.text(110,bl+0.005, 'baseline')
