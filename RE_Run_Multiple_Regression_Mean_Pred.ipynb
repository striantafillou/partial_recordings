# %% [markdown]
# # Load Layer outputs

# %%
nn = 'NN'

import pickle
with open('results/' +nn+'_layer_outputs.dat','rb') as f:
    layer_outs,layer_outs_test= pickle.load(f)
f.close()

# %% [markdown]
# # Load recording and test data

# %%
import numpy as np
from keras.datasets import mnist
from scipy.misc import imresize

(Xtrain, Ytrain), (Xtest, Ytest) = mnist.load_data()

(ntrain, xdim, ydim) = Xtrain.shape
ntest = Xtest.shape[0]

# Recording data
X_pr = Xtrain[30000:60000, :, :]
Y_pr = Ytrain[30000:60000]

# downsample
factor = 0.25

Xtest_down = np.ones((Xtest.shape[0], int(xdim*factor), int(ydim*factor)))
for i in range(Xtest.shape[0]):
    Xtest_down[i,:,:] = imresize(Xtest[i,:,:], factor)

X_pr_down = np.ones((X_pr.shape[0], int(xdim*factor), int(ydim*factor)))
for i in range(X_pr.shape[0]):
    X_pr_down[i,:,:] = imresize(X_pr[i,:,:], factor)
    
# VECTORIZE IMAGES
Xtest_down = Xtest_down.reshape(ntest, int(xdim*factor)**2).astype('float32') / 255
X_pr_down = X_pr_down.reshape(X_pr_down.shape[0], int(xdim*factor)**2).astype('float32') / 255
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run Multiple Regressions and Average Predictions

# %%
from copy import copy, deepcopy
from RE_PartialRecData2 import RE_PartialRecData2
from sklearn import preprocessing, linear_model
import pickle


# how many recordings?
nRecordings = 10
# how many neurons from the firs hidden layer?
subnetSize = [2**x for x in range(8)]
#subnetSize =[1]
nSubnetSize = len(subnetSize)
# which layers?
iLayer=0
# how many samples per recording?
nSamples = np.divide(int(X_pr_down.shape[0]/nRecordings),subnetSize)*100
# how many iterations
nIterations = 5

# baseline prediction error
#bl = np.std(layer_outs_test[oLayer]-np.mean(layer_outs_test[oLayer]));

oLayer = len(layer_outs)-1  # index of output layer
nOutNeurons = layer_outs[oLayer].shape[1]
rmses = np.zeros([nIterations, nOutNeurons, nSubnetSize])

for iLayer in range(len(layer_outs)-1):
    for ss in range(nSubnetSize):
        #r_coefs =np.zeros((nIterations, 10, 128))
        #nLayerNeurons = [subnetSize[ss], 0, 0, 0, 10]
        nLayerNeurons = subnetSize[ss]
        print(subnetSize[ss])
        for it in range(nIterations):
            # copy data - is this necessary?
            layer_outputs = deepcopy(layer_outs)
            rmses_rec = np.zeros((nRecordings, nOutNeurons))
            for iRec in range(nRecordings):
                # subsample
                X_subsample, Y_subsample = RE_PartialRecData2(layer_outputs[iLayer], layer_outputs[oLayer], \
                                                              nLayerNeurons, 1, nSamples[ss])
                # impute X_subsample with mean value, apply imputation to test set
                imp =preprocessing.Imputer(missing_values='NaN', strategy='mean')
                impf =imp.fit(X_subsample)
                X_new = impf.transform(X_subsample)
                (rem_cols, ) = np.where(np.sum(np.abs(X_new), axis=0)==0)
                if rem_cols.shape[0]>0:
                    print('Removing cols #', rem_cols)
                X_test_new= impf.transform(layer_outs_test[iLayer])
                # fit regression model
                #regr = linear_model.Lasso(0.01)
                regr =linear_model.LinearRegression()
                regr.fit(X_new, Y_subsample)
                rmses_rec[iRec, :] = np.sqrt(np.mean((regr.predict(X_test_new) - layer_outs_test[oLayer])**2, axis=0))
            #print(rmses_rec)

            rmses[it,:,ss] = np.mean(rmses_rec, axis=0)

            print ('predicting, mean RMSEs=%f' %np.mean(rmses[it, :, ss]))

    fName = 'results/LRMP_RMSES_Layer'+str(iLayer) + 'nRec' + str(nRecordings) + nn + '.dat'
    # save the rmse's
    with open(fName,'wb') as f:
        pickle.dump(rmses, f)
    f.close()
# Out:
# 1
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.291297
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.292500
# predicting, mean RMSEs=0.292413
# predicting, mean RMSEs=0.292870
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.293235
# 2
# ('Removing cols #', array([0, 1]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.288233
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.288147
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.289546
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.287611
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0, 1]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.289737
# 4
# ('Removing cols #', array([3]))
# ('Removing cols #', array([3]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.281532
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0, 1]))
# ('Removing cols #', array([0, 1]))
# ('Removing cols #', array([0, 3]))
# predicting, mean RMSEs=0.279792
# ('Removing cols #', array([2]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1, 3]))
# predicting, mean RMSEs=0.277970
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.276702
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1, 2]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.277676
# 8
# ('Removing cols #', array([1, 5]))
# ('Removing cols #', array([0, 2]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.259697
# ('Removing cols #', array([3]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([2, 6]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([1, 3]))
# ('Removing cols #', array([6]))
# predicting, mean RMSEs=0.264513
# ('Removing cols #', array([7]))
# ('Removing cols #', array([2, 4, 5]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([6]))
# predicting, mean RMSEs=0.262600
# ('Removing cols #', array([3]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([0, 1, 3]))
# predicting, mean RMSEs=0.262250
# ('Removing cols #', array([2, 5, 7]))
# ('Removing cols #', array([0, 6]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([1, 7]))
# ('Removing cols #', array([0, 1, 3]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.266663
# 16
# ('Removing cols #', array([ 4,  8, 14]))
# ('Removing cols #', array([1, 5, 9]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([0, 6, 9]))
# ('Removing cols #', array([ 7, 15]))
# ('Removing cols #', array([ 1, 14]))
# ('Removing cols #', array([ 3,  4, 15]))
# ('Removing cols #', array([ 4, 12]))
# ('Removing cols #', array([3, 9]))
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.235050
# ('Removing cols #', array([15]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([ 2,  3,  8, 12]))
# ('Removing cols #', array([ 8, 11]))
# ('Removing cols #', array([1, 5]))
# ('Removing cols #', array([ 0,  2,  3,  4, 14]))
# ('Removing cols #', array([10]))
# ('Removing cols #', array([ 0,  3,  4, 12, 13]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([ 3, 15]))
# predicting, mean RMSEs=0.238149
# ('Removing cols #', array([11, 12]))
# ('Removing cols #', array([11]))
# ('Removing cols #', array([ 9, 15]))
# ('Removing cols #', array([ 1,  7, 11]))
# ('Removing cols #', array([3, 9]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([12, 15]))
# ('Removing cols #', array([ 8, 13]))
# ('Removing cols #', array([ 4,  8, 15]))
# predicting, mean RMSEs=0.239329
# ('Removing cols #', array([ 5, 11]))
# ('Removing cols #', array([ 4, 13]))
# ('Removing cols #', array([ 7, 14]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([ 1,  4, 15]))
# ('Removing cols #', array([ 3, 13]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([ 3, 11]))
# predicting, mean RMSEs=0.238255
# ('Removing cols #', array([8]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([ 3,  4,  6,  7, 15]))
# ('Removing cols #', array([ 8, 13]))
# ('Removing cols #', array([ 3,  7, 14]))
# ('Removing cols #', array([ 1, 12, 15]))
# ('Removing cols #', array([ 3, 11, 14]))
# ('Removing cols #', array([ 2,  3, 15]))
# predicting, mean RMSEs=0.239319
# 32
# ('Removing cols #', array([ 2,  7,  9, 14]))
# ('Removing cols #', array([ 0,  1, 10, 11]))
# ('Removing cols #', array([ 0,  2, 23, 31]))
# ('Removing cols #', array([13, 22, 31]))
# ('Removing cols #', array([ 9, 10]))
# ('Removing cols #', array([ 3,  5, 15, 31]))
# ('Removing cols #', array([19, 30]))
# ('Removing cols #', array([ 1,  2,  3, 14]))
# ('Removing cols #', array([ 6,  7, 11, 31]))
# ('Removing cols #', array([ 9, 19, 21, 30]))
# predicting, mean RMSEs=0.210792
# ('Removing cols #', array([13, 24, 30]))
# ('Removing cols #', array([10, 15, 24, 26]))
# ('Removing cols #', array([ 1,  3,  5,  7, 18, 30]))
# ('Removing cols #', array([ 1,  8, 12, 17]))
# ('Removing cols #', array([ 1,  4,  5, 24, 30]))
# ('Removing cols #', array([ 6, 19]))
# ('Removing cols #', array([ 2,  3,  6, 30]))
# ('Removing cols #', array([ 1,  4, 24]))
# ('Removing cols #', array([ 0,  3,  6, 14, 16, 17, 27]))
# predicting, mean RMSEs=0.207659
# ('Removing cols #', array([14]))
# ('Removing cols #', array([ 2,  8, 24, 25, 31]))
# ('Removing cols #', array([ 2,  3,  5,  7,  9, 25, 26]))
# ('Removing cols #', array([ 0,  2,  4, 14, 15, 25, 30]))
# ('Removing cols #', array([ 8,  9, 18, 27, 31]))
# ('Removing cols #', array([ 5,  9, 13, 14, 23, 25]))
# ('Removing cols #', array([ 8, 23]))
# ('Removing cols #', array([ 1,  4,  7,  8, 14]))
# ('Removing cols #', array([10, 15, 16]))
# ('Removing cols #', array([ 4,  6, 14, 16, 30]))
# predicting, mean RMSEs=0.207933
# ('Removing cols #', array([ 1, 10, 23]))
# ('Removing cols #', array([ 2,  6, 10, 16, 28, 31]))
# ('Removing cols #', array([ 4,  8, 14, 22]))
# ('Removing cols #', array([ 3, 13]))
# ('Removing cols #', array([17, 24]))
# ('Removing cols #', array([ 0,  5,  7, 16, 22, 24, 30]))
# ('Removing cols #', array([ 5,  7, 19, 22, 31]))
# ('Removing cols #', array([ 4, 31]))
# ('Removing cols #', array([13, 14, 17, 21, 22, 24, 30]))
# ('Removing cols #', array([ 1,  5, 10, 15, 17]))
# predicting, mean RMSEs=0.206138
# ('Removing cols #', array([ 5,  9, 13, 14, 15, 26]))
# ('Removing cols #', array([ 0, 13, 15, 28]))
# ('Removing cols #', array([ 3,  6, 19, 21, 28, 30]))
# ('Removing cols #', array([ 4,  8, 13, 22]))
# ('Removing cols #', array([12, 30]))
# ('Removing cols #', array([ 1,  4, 14]))
# ('Removing cols #', array([20, 29, 31]))
# ('Removing cols #', array([ 2,  6, 18, 20, 29, 30]))
# ('Removing cols #', array([ 0,  5,  7, 12, 20, 21, 30, 31]))
# ('Removing cols #', array([13, 17, 20]))
# predicting, mean RMSEs=0.210127
# 64
# ('Removing cols #', array([ 6,  9, 14, 16, 29, 48, 50, 52]))
# ('Removing cols #', array([ 6, 10, 30, 45, 47, 49]))
# ('Removing cols #', array([ 8, 14, 17, 59]))
# ('Removing cols #', array([ 4, 15, 17, 19, 20, 31, 32, 35, 51, 59]))
# ('Removing cols #', array([ 1, 15, 19, 22, 32, 34, 35, 60]))
# ('Removing cols #', array([ 2,  4,  7, 10, 14, 17, 18, 29, 45, 47, 62]))
# ('Removing cols #', array([ 1,  4, 11, 25, 27, 31, 48, 49, 60, 63]))
# ('Removing cols #', array([ 7, 12, 16, 17, 26, 30, 46, 47, 62]))
# ('Removing cols #', array([ 3,  7, 11, 15, 18, 33, 62]))
# ('Removing cols #', array([ 2, 10, 17, 18, 25, 30, 46]))
# predicting, mean RMSEs=0.179687
# ('Removing cols #', array([ 3,  9, 13, 20, 36, 50, 63]))
# ('Removing cols #', array([ 1, 15, 18, 44, 46, 62]))
# ('Removing cols #', array([ 3, 13, 16, 18, 30, 33, 49, 52]))
# ('Removing cols #', array([ 4, 27, 29, 30, 46, 50, 62]))
# ('Removing cols #', array([ 6, 10, 13, 27, 28, 31, 46]))
# ('Removing cols #', array([ 1,  5,  8, 15, 17, 44, 48, 59, 62]))
# ('Removing cols #', array([ 2,  3,  8, 12, 14, 27, 47, 49, 63]))
# ('Removing cols #', array([ 1, 10, 16, 18, 30, 45, 47, 61, 63]))
# ('Removing cols #', array([ 1,  8, 10, 13, 16, 17, 25, 27, 31, 51, 60, 62]))
# ('Removing cols #', array([ 1,  3, 10, 14, 17, 19, 21, 33, 36, 59]))
# predicting, mean RMSEs=0.175805
# ('Removing cols #', array([ 1, 11, 13, 27, 46, 48, 50]))
# ('Removing cols #', array([ 2, 10, 13, 26, 29, 31, 48]))
# ('Removing cols #', array([ 2,  4, 10, 13, 15, 17, 31, 33, 48, 63]))
# ('Removing cols #', array([ 1,  3, 11, 13, 17, 19, 31, 32, 49]))
# ('Removing cols #', array([ 1,  4, 12, 14, 17, 30, 33, 45]))
# ('Removing cols #', array([ 5,  8, 13, 15, 30, 31, 60]))
# ('Removing cols #', array([15, 28, 33, 35, 53]))
# ('Removing cols #', array([ 1, 15, 27, 46, 63]))
# ('Removing cols #', array([ 5, 15, 18, 32, 34, 48, 52, 61]))
# ('Removing cols #', array([ 3, 10, 13, 28, 29, 31, 45, 46, 60]))
# predicting, mean RMSEs=0.176075
# ('Removing cols #', array([ 2,  4, 10, 14, 19, 31, 33, 45, 60]))
# ('Removing cols #', array([12, 16, 19, 30, 49, 52, 62]))
# ('Removing cols #', array([ 1,  8, 10, 18, 29, 33, 35, 51]))
# ('Removing cols #', array([ 3,  4, 15, 16, 28, 30, 48, 50, 63]))
# ('Removing cols #', array([ 0,  8, 10, 14, 16, 28, 30, 32, 47, 49, 62]))
# ('Removing cols #', array([10, 13, 16, 27, 28, 31, 45, 47, 62]))
# ('Removing cols #', array([ 2,  9, 15, 16, 26, 29, 43, 46, 62]))
# ('Removing cols #', array([ 2, 10, 12, 14, 16, 30, 34, 62]))
# ('Removing cols #', array([ 5,  9, 11, 16, 18, 33, 34, 50, 62]))
# ('Removing cols #', array([ 1,  5,  9, 12, 26, 28, 31, 50]))
# predicting, mean RMSEs=0.178501
# ('Removing cols #', array([ 6,  7, 11, 12, 27, 30, 49]))
# ('Removing cols #', array([ 3,  9, 15, 17, 18, 34, 36, 51, 61]))
# ('Removing cols #', array([ 3,  9, 11, 15, 29, 49, 51, 52]))
# ('Removing cols #', array([ 1,  9, 13, 17, 33, 35, 51, 63]))
# ('Removing cols #', array([ 2,  4,  9, 20, 30, 49, 51]))
# ('Removing cols #', array([ 3,  5, 10, 11, 27, 46, 50, 61, 63]))
# ('Removing cols #', array([ 1, 10, 18, 28, 47, 63]))
# ('Removing cols #', array([ 2,  7, 10, 14, 25, 26, 43, 45, 60]))
# ('Removing cols #', array([ 3,  9, 13, 17, 20, 34, 47, 51, 61]))
# ('Removing cols #', array([ 1,  3, 24, 25, 27, 44, 48]))
# predicting, mean RMSEs=0.177184
# 128
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,  96,
#         99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# predicting, mean RMSEs=0.154254
# ('Removing cols #', array([  6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,  96,
#         99, 122, 126]))
# ('Removing cols #', array([  6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,  96,
#         99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# predicting, mean RMSEs=0.154250
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# predicting, mean RMSEs=0.154045
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# predicting, mean RMSEs=0.154046
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,  96,
#         99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# ('Removing cols #', array([  3,   6,  15,  20,  25,  30,  34,  36,  57,  59,  63,  65,  92,
#         96,  99, 122, 126]))
# predicting, mean RMSEs=0.153984
# 1
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.291781
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.292007
# predicting, mean RMSEs=0.291376
# predicting, mean RMSEs=0.290858
# predicting, mean RMSEs=0.290489
# 2
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.286446
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.286734
# predicting, mean RMSEs=0.287109
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.283820
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.285247
# 4
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.274757
# ('Removing cols #', array([1]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.276233
# ('Removing cols #', array([0, 3]))
# predicting, mean RMSEs=0.274250
# ('Removing cols #', array([3]))
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.273644
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.275230
# 8
# ('Removing cols #', array([0]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([2, 4]))
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.255708
# ('Removing cols #', array([6]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.256735
# ('Removing cols #', array([5]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.253853
# ('Removing cols #', array([5]))
# ('Removing cols #', array([3, 5]))
# predicting, mean RMSEs=0.254722
# ('Removing cols #', array([0]))
# ('Removing cols #', array([7]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([3]))
# ('Removing cols #', array([7]))
# predicting, mean RMSEs=0.255914
# 16
# ('Removing cols #', array([15]))
# ('Removing cols #', array([ 3, 10]))
# ('Removing cols #', array([13]))
# ('Removing cols #', array([ 5,  9, 10]))
# ('Removing cols #', array([ 2, 15]))
# ('Removing cols #', array([ 2, 14]))
# ('Removing cols #', array([ 1,  3, 15]))
# ('Removing cols #', array([9]))
# predicting, mean RMSEs=0.225645
# ('Removing cols #', array([0]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([3]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([12]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([10, 15]))
# ('Removing cols #', array([14]))
# predicting, mean RMSEs=0.225458
# ('Removing cols #', array([15]))
# ('Removing cols #', array([ 1,  9, 14]))
# ('Removing cols #', array([ 7, 14]))
# ('Removing cols #', array([1, 3]))
# ('Removing cols #', array([ 1, 10]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([ 7, 11, 14]))
# ('Removing cols #', array([11]))
# predicting, mean RMSEs=0.230266
# ('Removing cols #', array([4]))
# ('Removing cols #', array([12]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([ 5, 14]))
# ('Removing cols #', array([10]))
# ('Removing cols #', array([6]))
# predicting, mean RMSEs=0.220669
# ('Removing cols #', array([ 4,  7, 14]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([11, 14, 15]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([4, 7]))
# ('Removing cols #', array([15]))
# ('Removing cols #', array([11]))
# predicting, mean RMSEs=0.229574
# 32
# ('Removing cols #', array([ 1, 12]))
# ('Removing cols #', array([ 0, 11]))
# ('Removing cols #', array([27, 31]))
# ('Removing cols #', array([ 1, 23]))
# ('Removing cols #', array([23, 28, 30]))
# ('Removing cols #', array([ 5, 11, 12, 23, 31]))
# ('Removing cols #', array([14, 27]))
# ('Removing cols #', array([14, 25]))
# ('Removing cols #', array([14, 22]))
# predicting, mean RMSEs=0.189085
# ('Removing cols #', array([12, 21]))
# ('Removing cols #', array([ 7, 22, 28]))
# ('Removing cols #', array([30]))
# ('Removing cols #', array([29]))
# ('Removing cols #', array([ 5,  6, 30]))
# ('Removing cols #', array([ 9, 17, 26, 28]))
# ('Removing cols #', array([ 8, 23, 29]))
# ('Removing cols #', array([ 7, 13]))
# ('Removing cols #', array([ 0,  8, 14]))
# predicting, mean RMSEs=0.189412
# ('Removing cols #', array([9]))
# ('Removing cols #', array([ 8, 24, 30]))
# ('Removing cols #', array([ 2,  7, 13, 24]))
# ('Removing cols #', array([ 0,  7,  9, 17, 24]))
# ('Removing cols #', array([ 9, 19, 30]))
# ('Removing cols #', array([ 7, 12, 31]))
# ('Removing cols #', array([31]))
# ('Removing cols #', array([ 8, 11]))
# predicting, mean RMSEs=0.186747
# ('Removing cols #', array([16, 29]))
# ('Removing cols #', array([12, 14, 23, 26]))
# ('Removing cols #', array([13, 15]))
# ('Removing cols #', array([ 1, 12, 29]))
# ('Removing cols #', array([ 9, 24, 29]))
# ('Removing cols #', array([ 8, 27]))
# ('Removing cols #', array([ 0, 23]))
# ('Removing cols #', array([ 0,  6, 23, 28]))
# ('Removing cols #', array([12, 25]))
# predicting, mean RMSEs=0.190903
# ('Removing cols #', array([13, 14, 30]))
# ('Removing cols #', array([12, 20, 25]))
# ('Removing cols #', array([ 7, 22]))
# ('Removing cols #', array([25, 31]))
# ('Removing cols #', array([ 2, 24]))
# ('Removing cols #', array([30]))
# ('Removing cols #', array([20, 27]))
# ('Removing cols #', array([15, 26, 31]))
# ('Removing cols #', array([ 7, 14]))
# ('Removing cols #', array([25]))
# predicting, mean RMSEs=0.189961
# 64
# ('Removing cols #', array([ 2, 14, 17, 29, 47, 61]))
# ('Removing cols #', array([ 1, 16, 26, 56]))
# ('Removing cols #', array([ 2, 15, 49]))
# ('Removing cols #', array([ 1, 15, 17, 28, 48, 59]))
# ('Removing cols #', array([14, 17, 45, 47, 61]))
# ('Removing cols #', array([ 2, 15, 17, 28, 49, 56, 62]))
# ('Removing cols #', array([18, 45, 48, 61]))
# ('Removing cols #', array([ 3, 15, 28, 29, 45]))
# ('Removing cols #', array([16, 18, 25, 27]))
# ('Removing cols #', array([ 2, 20, 22, 46]))
# predicting, mean RMSEs=0.153385
# ('Removing cols #', array([ 3, 17, 27, 29, 59]))
# ('Removing cols #', array([28, 30, 44, 46, 55]))
# ('Removing cols #', array([ 1,  9, 20, 46]))
# ('Removing cols #', array([ 3, 25, 55, 62]))
# ('Removing cols #', array([ 1, 22, 44, 56]))
# ('Removing cols #', array([12, 23, 45, 48]))
# ('Removing cols #', array([14, 19, 44, 48, 62]))
# ('Removing cols #', array([14, 17, 44, 47, 62]))
# ('Removing cols #', array([ 1, 11, 14, 25, 26, 49]))
# ('Removing cols #', array([ 2, 22, 52, 58]))
# predicting, mean RMSEs=0.154145
# ('Removing cols #', array([13, 23, 24, 43, 56]))
# ('Removing cols #', array([ 3, 15, 19, 31, 33, 47, 49, 55]))
# ('Removing cols #', array([ 3, 16, 28, 29, 58, 62]))
# ('Removing cols #', array([12, 14, 47, 61]))
# ('Removing cols #', array([ 0, 15, 17, 30, 31, 48, 61]))
# ('Removing cols #', array([11, 59]))
# ('Removing cols #', array([ 1, 13, 15, 26, 27, 44, 46, 57]))
# ('Removing cols #', array([14, 26]))
# ('Removing cols #', array([ 2, 26, 28, 44]))
# ('Removing cols #', array([ 2, 15, 31, 45, 48, 62]))
# predicting, mean RMSEs=0.156080
# ('Removing cols #', array([ 2, 11, 16, 28, 46, 48]))
# ('Removing cols #', array([32, 58]))
# ('Removing cols #', array([ 1, 45, 48]))
# ('Removing cols #', array([ 3, 14, 16, 30, 31, 50, 61]))
# ('Removing cols #', array([ 4, 16, 31, 48, 51, 58]))
# ('Removing cols #', array([ 2, 19, 47, 62]))
# ('Removing cols #', array([11, 25, 44, 55]))
# ('Removing cols #', array([ 4, 21, 26, 36, 37]))
# ('Removing cols #', array([16, 19, 27, 62]))
# ('Removing cols #', array([ 2, 15, 18, 46, 48]))
# predicting, mean RMSEs=0.153980
# ('Removing cols #', array([16, 25, 46, 55]))
# ('Removing cols #', array([21, 28, 44, 55, 61]))
# ('Removing cols #', array([ 2, 31, 44]))
# ('Removing cols #', array([18, 49, 51, 57, 61]))
# ('Removing cols #', array([14, 17, 28, 29, 46, 48, 55, 61]))
# ('Removing cols #', array([ 2, 30, 32, 46, 60]))
# ('Removing cols #', array([ 4, 19, 30, 48, 61]))
# ('Removing cols #', array([ 1, 13, 25, 26, 41, 44]))
# ('Removing cols #', array([10, 13, 22, 23, 40, 44, 62]))
# ('Removing cols #', array([13, 16, 27, 50]))
# predicting, mean RMSEs=0.155720
# 128
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# predicting, mean RMSEs=0.131634
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# predicting, mean RMSEs=0.131564
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# predicting, mean RMSEs=0.131442
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# predicting, mean RMSEs=0.131678
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# ('Removing cols #', array([  4,  29,  34,  55,  57,  92,  97, 113, 123]))
# predicting, mean RMSEs=0.131753
# 1
# predicting, mean RMSEs=0.288296
# predicting, mean RMSEs=0.284988
# predicting, mean RMSEs=0.288759
# predicting, mean RMSEs=0.288959
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.291182
# 2
# predicting, mean RMSEs=0.279639
# predicting, mean RMSEs=0.280300
# predicting, mean RMSEs=0.277488
# predicting, mean RMSEs=0.278957
# predicting, mean RMSEs=0.279599
# 4
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.263162
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.267510
# ('Removing cols #', array([3]))
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.265613
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.266701
# predicting, mean RMSEs=0.267055
# 8
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.238303
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.234280
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.234949
# ('Removing cols #', array([6]))
# predicting, mean RMSEs=0.228741
# ('Removing cols #', array([6]))
# ('Removing cols #', array([5]))
# predicting, mean RMSEs=0.239367
# 16
# ('Removing cols #', array([14]))
# ('Removing cols #', array([15]))
# ('Removing cols #', array([10, 14]))
# ('Removing cols #', array([ 7, 14]))
# predicting, mean RMSEs=0.201162
# ('Removing cols #', array([15]))
# ('Removing cols #', array([11, 15]))
# ('Removing cols #', array([10]))
# ('Removing cols #', array([11]))
# predicting, mean RMSEs=0.197668
# ('Removing cols #', array([14]))
# ('Removing cols #', array([14]))
# ('Removing cols #', array([ 8, 12]))
# predicting, mean RMSEs=0.202872
# ('Removing cols #', array([9]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([ 8, 15]))
# predicting, mean RMSEs=0.203091
# ('Removing cols #', array([15]))
# predicting, mean RMSEs=0.202119
# 32
# ('Removing cols #', array([29]))
# ('Removing cols #', array([18]))
# ('Removing cols #', array([30]))
# ('Removing cols #', array([12, 27]))
# ('Removing cols #', array([12]))
# predicting, mean RMSEs=0.155622
# ('Removing cols #', array([30]))
# ('Removing cols #', array([31]))
# ('Removing cols #', array([16, 29]))
# ('Removing cols #', array([28]))
# ('Removing cols #', array([15]))
# ('Removing cols #', array([18]))
# predicting, mean RMSEs=0.152133
# ('Removing cols #', array([28]))
# ('Removing cols #', array([19]))
# ('Removing cols #', array([17]))
# ('Removing cols #', array([17, 31]))
# ('Removing cols #', array([29]))
# ('Removing cols #', array([29]))
# ('Removing cols #', array([31]))
# predicting, mean RMSEs=0.157147
# ('Removing cols #', array([18]))
# ('Removing cols #', array([16, 27]))
# ('Removing cols #', array([18]))
# predicting, mean RMSEs=0.155473
# ('Removing cols #', array([30]))
# ('Removing cols #', array([14, 28]))
# ('Removing cols #', array([16, 28]))
# predicting, mean RMSEs=0.156655
# 64
# ('Removing cols #', array([31, 58]))
# ('Removing cols #', array([37, 59]))
# ('Removing cols #', array([34, 58]))
# ('Removing cols #', array([35]))
# ('Removing cols #', array([37]))
# ('Removing cols #', array([24]))
# ('Removing cols #', array([32, 59]))
# ('Removing cols #', array([35]))
# predicting, mean RMSEs=0.125518
# ('Removing cols #', array([36]))
# ('Removing cols #', array([31]))
# ('Removing cols #', array([36, 57]))
# ('Removing cols #', array([33]))
# ('Removing cols #', array([34, 57]))
# ('Removing cols #', array([33, 59]))
# ('Removing cols #', array([35, 58]))
# ('Removing cols #', array([30, 55]))
# predicting, mean RMSEs=0.126215
# ('Removing cols #', array([58]))
# ('Removing cols #', array([34]))
# ('Removing cols #', array([32]))
# ('Removing cols #', array([60]))
# ('Removing cols #', array([29]))
# ('Removing cols #', array([59]))
# ('Removing cols #', array([39]))
# ('Removing cols #', array([60]))
# ('Removing cols #', array([34]))
# predicting, mean RMSEs=0.125971
# ('Removing cols #', array([58]))
# ('Removing cols #', array([59]))
# ('Removing cols #', array([38, 60]))
# ('Removing cols #', array([33, 57]))
# ('Removing cols #', array([37]))
# ('Removing cols #', array([38]))
# ('Removing cols #', array([34, 59]))
# ('Removing cols #', array([61]))
# ('Removing cols #', array([39]))
# predicting, mean RMSEs=0.127410
# ('Removing cols #', array([61]))
# ('Removing cols #', array([59]))
# ('Removing cols #', array([36, 59]))
# ('Removing cols #', array([39]))
# ('Removing cols #', array([35]))
# ('Removing cols #', array([58]))
# ('Removing cols #', array([35, 59]))
# ('Removing cols #', array([34, 58]))
# ('Removing cols #', array([35, 58]))
# predicting, mean RMSEs=0.127556
# 128
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# predicting, mean RMSEs=0.110308
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# predicting, mean RMSEs=0.110276
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# predicting, mean RMSEs=0.110279
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# predicting, mean RMSEs=0.110513
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# ('Removing cols #', array([ 69, 118]))
# predicting, mean RMSEs=0.110298
# 1
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.287547
# predicting, mean RMSEs=0.286515
# predicting, mean RMSEs=0.286279
# predicting, mean RMSEs=0.288145
# predicting, mean RMSEs=0.288318
# 2
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.279296
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.280449
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.276084
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.277840
# predicting, mean RMSEs=0.277107
# 4
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.258456
# ('Removing cols #', array([0]))
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.259652
# predicting, mean RMSEs=0.252345
# ('Removing cols #', array([3]))
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.257459
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([3]))
# predicting, mean RMSEs=0.259838
# 8
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.225222
# ('Removing cols #', array([0]))
# ('Removing cols #', array([5]))
# predicting, mean RMSEs=0.220228
# ('Removing cols #', array([0]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.228495
# ('Removing cols #', array([7]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([6]))
# ('Removing cols #', array([7]))
# predicting, mean RMSEs=0.222589
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.221560
# 16
# ('Removing cols #', array([1, 3]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([0]))
# ('Removing cols #', array([1, 3]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.179574
# ('Removing cols #', array([14]))
# ('Removing cols #', array([3]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([3, 6]))
# ('Removing cols #', array([0]))
# predicting, mean RMSEs=0.177478
# ('Removing cols #', array([ 2,  5, 11]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([ 0,  1, 10]))
# ('Removing cols #', array([ 0, 11]))
# ('Removing cols #', array([1]))
# predicting, mean RMSEs=0.180037
# ('Removing cols #', array([ 2, 14]))
# ('Removing cols #', array([2, 6]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([ 2, 14]))
# ('Removing cols #', array([11]))
# ('Removing cols #', array([15]))
# predicting, mean RMSEs=0.176227
# ('Removing cols #', array([1]))
# ('Removing cols #', array([0, 1]))
# ('Removing cols #', array([15]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([15]))
# ('Removing cols #', array([2]))
# predicting, mean RMSEs=0.176918
# 32
# ('Removing cols #', array([19]))
# ('Removing cols #', array([ 2, 18]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([16]))
# ('Removing cols #', array([2, 3, 5]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([9]))
# ('Removing cols #', array([3, 5]))
# ('Removing cols #', array([3, 4]))
# predicting, mean RMSEs=0.136020
# ('Removing cols #', array([ 3, 30]))
# ('Removing cols #', array([3, 5]))
# ('Removing cols #', array([ 4, 20]))
# ('Removing cols #', array([17]))
# ('Removing cols #', array([1, 2]))
# ('Removing cols #', array([1]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([30]))
# predicting, mean RMSEs=0.137707
# ('Removing cols #', array([7]))
# ('Removing cols #', array([ 2,  5, 22]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([ 1, 23]))
# ('Removing cols #', array([ 1, 18]))
# predicting, mean RMSEs=0.137170
# ('Removing cols #', array([ 2, 17]))
# ('Removing cols #', array([2, 4]))
# ('Removing cols #', array([ 3, 18, 31]))
# ('Removing cols #', array([2]))
# ('Removing cols #', array([16]))
# ('Removing cols #', array([ 2,  4, 31]))
# ('Removing cols #', array([3]))
# ('Removing cols #', array([ 2, 29]))
# ('Removing cols #', array([ 3,  4, 20]))
# predicting, mean RMSEs=0.138446
# ('Removing cols #', array([ 3,  4, 18, 30]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([5]))
# ('Removing cols #', array([ 1, 19]))
# ('Removing cols #', array([ 8, 30]))
# ('Removing cols #', array([ 1, 19]))
# ('Removing cols #', array([3]))
# ('Removing cols #', array([ 3,  6, 22, 30]))
# predicting, mean RMSEs=0.139191
# 64
# ('Removing cols #', array([34, 62]))
# ('Removing cols #', array([ 4,  9, 19, 43, 62]))
# ('Removing cols #', array([ 7,  8, 18, 40, 42]))
# ('Removing cols #', array([ 4,  7, 14, 41, 61]))
# ('Removing cols #', array([ 5,  6, 16, 43, 61]))
# ('Removing cols #', array([ 3, 14, 39, 46]))
# ('Removing cols #', array([40, 63]))
# ('Removing cols #', array([7, 8]))
# ('Removing cols #', array([ 4,  7, 36, 42]))
# ('Removing cols #', array([ 4,  7, 41]))
# predicting, mean RMSEs=0.115817
# ('Removing cols #', array([ 5, 11, 15]))
# ('Removing cols #', array([ 3, 12, 38]))
# ('Removing cols #', array([ 5,  6, 44]))
# ('Removing cols #', array([ 5,  8, 17, 38, 42]))
# ('Removing cols #', array([ 9, 45]))
# ('Removing cols #', array([35, 39, 40, 61]))
# ('Removing cols #', array([ 4,  9, 40]))
# ('Removing cols #', array([ 4,  5, 14, 39, 61]))
# ('Removing cols #', array([ 6, 11, 21, 42, 44]))
# ('Removing cols #', array([ 5,  6, 14, 43]))
# predicting, mean RMSEs=0.115279
# ('Removing cols #', array([ 8, 16, 38, 42]))
# ('Removing cols #', array([ 4,  9, 42]))
# ('Removing cols #', array([ 2,  6, 45, 47]))
# ('Removing cols #', array([ 4, 37, 40, 41, 61]))
# ('Removing cols #', array([ 7,  8, 35, 42]))
# ('Removing cols #', array([4]))
# ('Removing cols #', array([ 5, 40, 61]))
# ('Removing cols #', array([ 6,  7, 12, 44]))
# ('Removing cols #', array([34, 60]))
# ('Removing cols #', array([ 9, 43]))
# predicting, mean RMSEs=0.117133
# ('Removing cols #', array([ 3,  4, 13, 41, 44]))
# ('Removing cols #', array([ 6,  7, 11, 41]))
# ('Removing cols #', array([ 3,  6, 41, 60]))
# ('Removing cols #', array([ 5, 17, 47]))
# ('Removing cols #', array([ 8,  9, 39, 43]))
# ('Removing cols #', array([ 6, 16, 40, 59]))
# ('Removing cols #', array([ 4, 37, 59]))
# ('Removing cols #', array([ 7, 37, 59]))
# ('Removing cols #', array([ 4,  5, 38, 60]))
# ('Removing cols #', array([ 5,  7, 13, 37, 41]))
# predicting, mean RMSEs=0.116256
# ('Removing cols #', array([ 3,  6, 45]))
# ('Removing cols #', array([36, 40, 60]))
# ('Removing cols #', array([ 5,  6, 43]))
# ('Removing cols #', array([ 7, 10, 61]))
# ('Removing cols #', array([ 4,  5,  8, 41, 45, 46]))
# ('Removing cols #', array([ 4, 12, 35, 60]))
# ('Removing cols #', array([ 5, 10, 17, 45]))
# ('Removing cols #', array([ 4,  8, 17, 42, 44]))
# ('Removing cols #', array([ 8,  9, 13, 38, 60]))
# ('Removing cols #', array([ 8, 41, 60]))
# predicting, mean RMSEs=0.115847
# 128
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  81, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# predicting, mean RMSEs=0.104208
# ('Removing cols #', array([ 10,  11,  17,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  81, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# predicting, mean RMSEs=0.104424
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  84, 123]))
# predicting, mean RMSEs=0.104059
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# predicting, mean RMSEs=0.104245
# ('Removing cols #', array([ 10,  11,  17,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  81,  84, 123]))
# ('Removing cols #', array([ 10,  11,  17,  29,  73,  84, 123]))
# predicting, mean RMSEs=0.103975
