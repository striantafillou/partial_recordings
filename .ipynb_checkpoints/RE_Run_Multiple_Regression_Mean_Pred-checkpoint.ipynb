# %% [markdown]
# # Load Layer outputs

# %%
nn = 'LNN'

import pickle
with open('results/' +nn+'_layer_outputs.dat','rb') as f:
    layer_outs,layer_outs_test= pickle.load(f)
f.close()

# %% [markdown]
# # Load recording and test data

# %%
import numpy as np
from keras.datasets import mnist
from scipy.misc import imresize

(Xtrain, Ytrain), (Xtest, Ytest) = mnist.load_data()

(ntrain, xdim, ydim) = Xtrain.shape
ntest = Xtest.shape[0]

# Recording data
X_pr = Xtrain[30000:60000, :, :]
Y_pr = Ytrain[30000:60000]

# downsample
factor = 0.25

Xtest_down = np.ones((Xtest.shape[0], int(xdim*factor), int(ydim*factor)))
for i in range(Xtest.shape[0]):
    Xtest_down[i,:,:] = imresize(Xtest[i,:,:], factor)

X_pr_down = np.ones((X_pr.shape[0], int(xdim*factor), int(ydim*factor)))
for i in range(X_pr.shape[0]):
    X_pr_down[i,:,:] = imresize(X_pr[i,:,:], factor)
    
# VECTORIZE IMAGES
Xtest_down = Xtest_down.reshape(ntest, int(xdim*factor)**2).astype('float32') / 255
X_pr_down = X_pr_down.reshape(X_pr_down.shape[0], int(xdim*factor)**2).astype('float32') / 255
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run Multiple Regressions

# %%
from copy import copy, deepcopy
from RE_PartialRecData2 import RE_PartialRecData2
from sklearn import preprocessing, linear_model
import pickle


# how many recordings?
nRecordings = 10
# how many neurons from the firs hidden layer?
subnetSize = [2**x for x in range(8)]
#subnetSize =[1]
nSubnetSize = len(subnetSize)
# which layers?
iLayer=0
# how many samples per recording?
nSamples = np.divide(int(X_pr_down.shape[0]/nRecordings),subnetSize)*100
# how many iterations
nIterations = 5

# baseline prediction error
#bl = np.std(layer_outs_test[oLayer]-np.mean(layer_outs_test[oLayer]));

oLayer = len(layer_outs)-1  # index of output layer
nOutNeurons = layer_outs[oLayer].shape[1]
rmses = np.zeros([nIterations, nOutNeurons, nSubnetSize])

for iLayer in range(len(layer_outs)-1):
    for ss in range(nSubnetSize):
        #r_coefs =np.zeros((nIterations, 10, 128))
        #nLayerNeurons = [subnetSize[ss], 0, 0, 0, 10]
        nLayerNeurons = subnetSize[ss]
        print(subnetSize[ss])
        for it in range(nIterations):
            # copy data - is this necessary?
            layer_outputs = deepcopy(layer_outs)
            rmses_rec = np.zeros((nRecordings, nOutNeurons))
            for iRec in range(nRecordings):
                # subsample
                X_subsample, Y_subsample = RE_PartialRecData2(layer_outputs[iLayer], layer_outputs[oLayer], \
                                                              nLayerNeurons, 1, nSamples[ss])
                # impute X_subsample with mean value, apply imputation to test set
                imp =preprocessing.Imputer(missing_values='NaN', strategy='mean')
                impf =imp.fit(X_subsample)
                X_new = impf.transform(X_subsample)
                (rem_cols, ) = np.where(np.sum(X_new, axis=0)==0)
                if rem_cols.shape[0]>0:
                    print('Removing cols #', rem_cols)
                X_test_new= impf.transform(layer_outs_test[iLayer])
                # fit regression model
                #regr = linear_model.Lasso(0.01)
                regr =linear_model.LinearRegression()
                regr.fit(X_new, Y_subsample)
                rmses_rec[iRec, :] = np.sqrt(np.mean((regr.predict(X_test_new) - layer_outs_test[oLayer])**2, axis=0))
            #print(rmses_rec)

            rmses[it,:,ss] = np.mean(rmses_rec, axis=0)

            print ('predicting, mean RMSEs=%f' %np.mean(rmses[it, :, ss]))

    fName = 'LRMP_RMSES_Layer'+str(iLayer) + 'nRec' + str(nRecordings) + nn + '.dat'
    # save the rmse's
    with open(fName,'wb') as f:
        pickle.dump(rmses, f)
    f.close()
# Out:
# 1
# predicting, mean RMSEs=0.467198
# predicting, mean RMSEs=0.482724
# predicting, mean RMSEs=0.482881
# predicting, mean RMSEs=0.476296
# predicting, mean RMSEs=0.457479
# 2
# predicting, mean RMSEs=0.399711
# predicting, mean RMSEs=0.427038
# predicting, mean RMSEs=0.411937
# predicting, mean RMSEs=0.423042
# predicting, mean RMSEs=0.429140
# 4
# predicting, mean RMSEs=0.375696
# predicting, mean RMSEs=0.334552
# predicting, mean RMSEs=0.376142
# predicting, mean RMSEs=0.375035
# predicting, mean RMSEs=0.354044
# 8
# predicting, mean RMSEs=0.246987
# predicting, mean RMSEs=0.251650
# predicting, mean RMSEs=0.230231
# predicting, mean RMSEs=0.225423
# predicting, mean RMSEs=0.219071
# 16
# predicting, mean RMSEs=0.145929
# predicting, mean RMSEs=0.122039
# predicting, mean RMSEs=0.136292
# predicting, mean RMSEs=0.130646
# predicting, mean RMSEs=0.114345
# 32
# predicting, mean RMSEs=0.032904
# predicting, mean RMSEs=0.028673
# predicting, mean RMSEs=0.038667
# predicting, mean RMSEs=0.032783
# predicting, mean RMSEs=0.031495
# 64
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# 128
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# 1
# predicting, mean RMSEs=0.433009
# predicting, mean RMSEs=0.426188
# predicting, mean RMSEs=0.400151
# predicting, mean RMSEs=0.429804
# predicting, mean RMSEs=0.456249
# 2
# predicting, mean RMSEs=0.390670
# predicting, mean RMSEs=0.394969
# predicting, mean RMSEs=0.390974
# predicting, mean RMSEs=0.373121
# predicting, mean RMSEs=0.394984
# 4
# predicting, mean RMSEs=0.295124
# predicting, mean RMSEs=0.293218
# predicting, mean RMSEs=0.305427
# predicting, mean RMSEs=0.308884
# predicting, mean RMSEs=0.366484
# 8
# predicting, mean RMSEs=0.187959
# predicting, mean RMSEs=0.203252
# predicting, mean RMSEs=0.207507
# predicting, mean RMSEs=0.194999
# predicting, mean RMSEs=0.222605
# 16
# predicting, mean RMSEs=0.096300
# predicting, mean RMSEs=0.096929
# predicting, mean RMSEs=0.097557
# predicting, mean RMSEs=0.100828
# predicting, mean RMSEs=0.097173
# 32
# predicting, mean RMSEs=0.021417
# predicting, mean RMSEs=0.023853
# predicting, mean RMSEs=0.023618
# predicting, mean RMSEs=0.023665
# predicting, mean RMSEs=0.023451
# 64
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# 128
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# 1
# predicting, mean RMSEs=0.414924
# predicting, mean RMSEs=0.389568
# predicting, mean RMSEs=0.445520
# predicting, mean RMSEs=0.422913
# predicting, mean RMSEs=0.473368
# 2
# predicting, mean RMSEs=0.380210
# predicting, mean RMSEs=0.338516
# predicting, mean RMSEs=0.348325
# predicting, mean RMSEs=0.355025
# predicting, mean RMSEs=0.385452
# 4
# predicting, mean RMSEs=0.278598
# predicting, mean RMSEs=0.252133
# predicting, mean RMSEs=0.260635
# predicting, mean RMSEs=0.255024
# predicting, mean RMSEs=0.262191
# 8
# predicting, mean RMSEs=0.179450
# predicting, mean RMSEs=0.155265
# predicting, mean RMSEs=0.166280
# predicting, mean RMSEs=0.168595
# predicting, mean RMSEs=0.151512
# 16
# predicting, mean RMSEs=0.069523
# predicting, mean RMSEs=0.073917
# predicting, mean RMSEs=0.071988
# predicting, mean RMSEs=0.077054
# predicting, mean RMSEs=0.075234
# 32
# predicting, mean RMSEs=0.016912
# predicting, mean RMSEs=0.016540
# predicting, mean RMSEs=0.018413
# predicting, mean RMSEs=0.018270
# predicting, mean RMSEs=0.016197
# 64
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# 128
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# 1
# predicting, mean RMSEs=0.422834
# predicting, mean RMSEs=0.356254
# predicting, mean RMSEs=0.395449
# predicting, mean RMSEs=0.404771
# predicting, mean RMSEs=0.455037
# 2
# predicting, mean RMSEs=0.289566
# predicting, mean RMSEs=0.393166
# predicting, mean RMSEs=0.381678
# predicting, mean RMSEs=0.407583
# predicting, mean RMSEs=0.372649
# 4
# predicting, mean RMSEs=0.211827
# predicting, mean RMSEs=0.222187
# predicting, mean RMSEs=0.223956
# predicting, mean RMSEs=0.226993
# predicting, mean RMSEs=0.204358
# 8
# predicting, mean RMSEs=0.142450
# predicting, mean RMSEs=0.128427
# predicting, mean RMSEs=0.143424
# predicting, mean RMSEs=0.143377
# predicting, mean RMSEs=0.140212
# 16
# predicting, mean RMSEs=0.060050
# predicting, mean RMSEs=0.056943
# predicting, mean RMSEs=0.060854
# predicting, mean RMSEs=0.057304
# predicting, mean RMSEs=0.060178
# 32
# predicting, mean RMSEs=0.014600
# predicting, mean RMSEs=0.013186
# predicting, mean RMSEs=0.013018
# predicting, mean RMSEs=0.013087
# predicting, mean RMSEs=0.013025
# 64
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# 128
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
# predicting, mean RMSEs=0.000000
