# %% [markdown]
# # Load Layer outputs

# %%
nn = 'NN'

import pickle
with open('results/' + nn + '_layer_outputs.dat', 'rb') as f:
    layer_outs,layer_outs_test= pickle.load(f)
f.close()

# %% [markdown]
# # Load recording and test data

# %%
import numpy as np
from keras.datasets import mnist
from scipy.misc import imresize

(Xtrain, Ytrain), (Xtest, Ytest) = mnist.load_data()

(ntrain, xdim, ydim) = Xtrain.shape
ntest = Xtest.shape[0]

# Recording data
X_pr = Xtrain[30000:60000, :, :]
Y_pr = Ytrain[30000:60000]

# downsample
factor = 1
if factor<1:
    Xtest_down = np.ones((Xtest.shape[0], int(xdim*factor), int(ydim*factor)))
    for i in range(Xtest.shape[0]):
        Xtest_down[i,:,:] = imresize(Xtest[i,:,:], factor)

    X_pr_down = np.ones((X_pr.shape[0], int(xdim*factor), int(ydim*factor)))
    for i in range(X_pr.shape[0]):
        X_pr_down[i,:,:] = imresize(X_pr[i,:,:], factor)
else:
    Xtest_down = Xtest
    X_pr_down = X_pr
    
# VECTORIZE IMAGES
Xtest_down = Xtest_down.reshape(ntest, int(xdim*factor)**2).astype('float32') / 255
X_pr_down = X_pr_down.reshape(X_pr_down.shape[0], int(xdim*factor)**2).astype('float32') / 255
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run Neural Networks and average outputs

# %%
from copy import copy, deepcopy
from RE_PartialRecData2 import RE_PartialRecData2
from sklearn import preprocessing, linear_model
import pickle
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from keras.models import load_model
from keras.callbacks import EarlyStopping
from keras import backend as K
import tensorflow as tf

# how many recordings?
nRecordings = 10
# how many neurons from the firs hidden layer?
subnetSize = [2**x for x in range(8)]
nSubnetSize = len(subnetSize)
# which layers?
#iLayer = 0
# how many samples per recording?
nSamples = np.divide(int(X_pr_down.shape[0]/nRecordings),subnetSize)*100
# how many iterations
nIterations = 5

# baseline prediction error
#bl = np.std(layer_outs_test[oLayer]-np.mean(layer_outs_test[oLayer]));

oLayer = len(layer_outs)-1  # index of output layer
nOutNeurons = layer_outs[oLayer].shape[1]
rmses = np.zeros([nIterations, nOutNeurons, nSubnetSize])

for iLayer in range(0, len(layer_outs)-1,2):
    print('Layer #', iLayer)
    for ss in range(nSubnetSize):
        #r_coefs = np.zeros((nIterations, 10, 128))
        #nLayerNeurons = [subnetSize[ss], 0, 0, 0, 10]
        nLayerNeurons = subnetSize[ss]
        print(subnetSize[ss])
        for it in range(nIterations):
            # copy data - is this necessary?
            layer_outputs = deepcopy(layer_outs)
            rmses_rec = np.zeros((nRecordings, nOutNeurons))
            for iRec in range(nRecordings):
                # subsample
                X_subsample, Y_subsample = RE_PartialRecData2(layer_outputs[iLayer], layer_outputs[oLayer], 
                                                              nLayerNeurons, 1, nSamples[ss])
                # impute X_subsample with mean value, apply imputation to test set
                imp = preprocessing.Imputer(missing_values='NaN', strategy='mean')
                impf = imp.fit(X_subsample)
                X_new = impf.transform(X_subsample)
                (rem_cols, ) = np.where(np.sum(np.abs(X_new), axis=0)==0)
                if rem_cols.shape[0]>0:
                    print('Removing cols #', rem_cols)
                X_test_new = impf.transform(layer_outs_test[iLayer])
                # fit ΝΝ
                model = Sequential()
                model.add(Dense(16, input_shape=(X_new.shape[1],), activation='relu'))
                model.add(Dense(16, activation='relu'))
                model.add(Dense(16, activation='relu'))                
                model.add(Dense(10, activation='softmax'))
                # Compile model
                model.compile(loss='mean_squared_error', optimizer='adam')
                callbacks = [EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=0)]
                model.fit(X_new, Y_subsample, nb_epoch=30, batch_size=16, shuffle=True, verbose=2, 
                          validation_split=0.1, callbacks=callbacks)

                rmses_rec[iRec, :] = np.sqrt(np.mean((model.predict(X_test_new) - layer_outs_test[oLayer])**2, axis=0))

            rmses[it,:,ss] = np.mean(rmses_rec, axis=0)

            print ('predicting, mean RMSEs=%f' %np.mean(rmses[it, :, ss]))
# Out:
# ('Layer #', 0)
# 1
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 88s - loss: 0.0889 - val_loss: 0.0889
# Epoch 2/30
# 87s - loss: 0.0889 - val_loss: 0.0889
# Epoch 3/30
# 89s - loss: 0.0889 - val_loss: 0.0889
# Epoch 4/30
# 83s - loss: 0.0889 - val_loss: 0.0889
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 83s - loss: 0.0857 - val_loss: 0.0856
# Epoch 2/30
# 82s - loss: 0.0857 - val_loss: 0.0856
# Epoch 3/30
# 81s - loss: 0.0856 - val_loss: 0.0856
# Epoch 4/30
# 83s - loss: 0.0856 - val_loss: 0.0856
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 82s - loss: 0.0874 - val_loss: 0.0873
# Epoch 2/30
# 84s - loss: 0.0872 - val_loss: 0.0873
# Epoch 3/30
# 83s - loss: 0.0872 - val_loss: 0.0872
# Epoch 4/30
# 83s - loss: 0.0872 - val_loss: 0.0872
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 82s - loss: 0.0871 - val_loss: 0.0869
# Epoch 2/30
# 82s - loss: 0.0870 - val_loss: 0.0870
# Epoch 3/30
# 81s - loss: 0.0870 - val_loss: 0.0868
# Epoch 4/30
# 83s - loss: 0.0870 - val_loss: 0.0868
# ('Removing cols #', array([0]))
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 83s - loss: 0.0889 - val_loss: 0.0889
# Epoch 2/30
# 82s - loss: 0.0889 - val_loss: 0.0889
# Epoch 3/30
# 82s - loss: 0.0889 - val_loss: 0.0889
# Epoch 4/30
# 85s - loss: 0.0889 - val_loss: 0.0889
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 82s - loss: 0.0845 - val_loss: 0.0844
# Epoch 2/30
# 83s - loss: 0.0844 - val_loss: 0.0843
# Epoch 3/30
# 81s - loss: 0.0844 - val_loss: 0.0843
# Epoch 4/30
# 85s - loss: 0.0844 - val_loss: 0.0843
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 81s - loss: 0.0820 - val_loss: 0.0819
# Epoch 2/30
# 81s - loss: 0.0819 - val_loss: 0.0818
# Epoch 3/30
# 81s - loss: 0.0818 - val_loss: 0.0818
# Epoch 4/30
# 84s - loss: 0.0818 - val_loss: 0.0818
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
#
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 87s - loss: 0.0853 - val_loss: 0.0849
# Epoch 2/30
# 87s - loss: 0.0851 - val_loss: 0.0848
# Epoch 3/30
# 86s - loss: 0.0850 - val_loss: 0.0848
# Epoch 4/30
# 87s - loss: 0.0850 - val_loss: 0.0848
# Epoch 5/30
# 84s - loss: 0.0850 - val_loss: 0.0847
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 87s - loss: 0.0826 - val_loss: 0.0823
# Epoch 2/30
# 87s - loss: 0.0825 - val_loss: 0.0823
# Epoch 3/30
# 86s - loss: 0.0825 - val_loss: 0.0823
# Epoch 4/30
# 89s - loss: 0.0825 - val_loss: 0.0823
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 85s - loss: 0.0850 - val_loss: 0.0849
# Epoch 2/30
# 89s - loss: 0.0849 - val_loss: 0.0849
# Epoch 3/30
# 86s - loss: 0.0848 - val_loss: 0.0849
# Epoch 4/30
# 89s - loss: 0.0848 - val_loss: 0.0849
# predicting, mean RMSEs=0.289925
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 86s - loss: 0.0860 - val_loss: 0.0859
# Epoch 2/30
# 87s - loss: 0.0859 - val_loss: 0.0859
# Epoch 3/30
# 86s - loss: 0.0859 - val_loss: 0.0859
# Epoch 4/30
# 91s - loss: 0.0859 - val_loss: 0.0859
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 89s - loss: 0.0844 - val_loss: 0.0842
# Epoch 2/30
# 88s - loss: 0.0842 - val_loss: 0.0842
# Epoch 3/30
# 86s - loss: 0.0842 - val_loss: 0.0841
# Epoch 4/30
# 87s - loss: 0.0842 - val_loss: 0.0842
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 90s - loss: 0.0858 - val_loss: 0.0857
# Epoch 2/30
# 88s - loss: 0.0856 - val_loss: 0.0856
# Epoch 3/30
# 88s - loss: 0.0856 - val_loss: 0.0856
# Epoch 4/30
# 87s - loss: 0.0856 - val_loss: 0.0856
# Epoch 5/30
# 88s - loss: 0.0856 - val_loss: 0.0857
# Epoch 6/30
# 88s - loss: 0.0856 - val_loss: 0.0856
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 89s - loss: 0.0848 - val_loss: 0.0845
# Epoch 2/30
# 90s - loss: 0.0846 - val_loss: 0.0845
# Epoch 3/30
# 88s - loss: 0.0846 - val_loss: 0.0844
# Epoch 4/30
# 90s - loss: 0.0846 - val_loss: 0.0844
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 89s - loss: 0.0858 - val_loss: 0.0857
# Epoch 2/30
# 89s - loss: 0.0857 - val_loss: 0.0857
# Epoch 3/30
# 91s - loss: 0.0856 - val_loss: 0.0856
# Epoch 4/30
# 88s - loss: 0.0856 - val_loss: 0.0856
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 86s - loss: 0.0852 - val_loss: 0.0849
# Epoch 2/30
# 83s - loss: 0.0850 - val_loss: 0.0848
# Epoch 3/30
# 85s - loss: 0.0850 - val_loss: 0.0849
# Epoch 4/30
# 82s - loss: 0.0850 - val_loss: 0.0849
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 83s - loss: 0.0852 - val_loss: 0.0851
# Epoch 2/30
# 84s - loss: 0.0851 - val_loss: 0.0852
# Epoch 3/30
# 83s - loss: 0.0851 - val_loss: 0.0851
# Epoch 4/30
# 83s - loss: 0.0851 - val_loss: 0.0851
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 85s - loss: 0.0868 - val_loss: 0.0869
# Epoch 2/30
# 85s - loss: 0.0867 - val_loss: 0.0870
# Epoch 3/30
# 84s - loss: 0.0867 - val_loss: 0.0868
# Epoch 4/30
# 83s - loss: 0.0867 - val_loss: 0.0869
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 84s - loss: 0.0831 - val_loss: 0.0829
# Epoch 2/30
# 84s - loss: 0.0827 - val_loss: 0.0827
# Epoch 3/30
# 86s - loss: 0.0827 - val_loss: 0.0828
# Epoch 4/30
# 86s - loss: 0.0827 - val_loss: 0.0827
# Epoch 5/30
# 93s - loss: 0.0827 - val_loss: 0.0827
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 85s - loss: 0.0874 - val_loss: 0.0873
# Epoch 2/30
# 88s - loss: 0.0873 - val_loss: 0.0872
# Epoch 3/30
# 87s - loss: 0.0872 - val_loss: 0.0873
# Epoch 4/30
# 87s - loss: 0.0872 - val_loss: 0.0872
# predicting, mean RMSEs=0.291977
# ('Removing cols #', array([0]))
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 86s - loss: 0.0888 - val_loss: 0.0889
# Epoch 2/30
# 84s - loss: 0.0888 - val_loss: 0.0889
# Epoch 3/30
# 87s - loss: 0.0888 - val_loss: 0.0889
# Epoch 4/30
# 87s - loss: 0.0888 - val_loss: 0.0889
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 87s - loss: 0.0889 - val_loss: 0.0889
# Epoch 2/30
# 88s - loss: 0.0889 - val_loss: 0.0889
# Epoch 3/30
# 84s - loss: 0.0889 - val_loss: 0.0889
# Epoch 4/30
# 84s - loss: 0.0889 - val_loss: 0.0889
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 84s - loss: 0.0826 - val_loss: 0.0824
# Epoch 2/30
# 83s - loss: 0.0824 - val_loss: 0.0824
# Epoch 3/30
# 82s - loss: 0.0824 - val_loss: 0.0824
# Epoch 4/30
# 84s - loss: 0.0824 - val_loss: 0.0824
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 84s - loss: 0.0873 - val_loss: 0.0873
# Epoch 2/30
# 84s - loss: 0.0872 - val_loss: 0.0873
# Epoch 3/30
# 83s - loss: 0.0872 - val_loss: 0.0873
# Epoch 4/30
# 82s - loss: 0.0872 - val_loss: 0.0873
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 86s - loss: 0.0857 - val_loss: 0.0857
# Epoch 2/30
# 85s - loss: 0.0856 - val_loss: 0.0857
# Epoch 3/30
# 86s - loss: 0.0856 - val_loss: 0.0857
# Epoch 4/30
# 85s - loss: 0.0856 - val_loss: 0.0856
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 88s - loss: 0.0856 - val_loss: 0.0855
# Epoch 2/30
# 88s - loss: 0.0854 - val_loss: 0.0855
# Epoch 3/30
# 87s - loss: 0.0854 - val_loss: 0.0855
# Epoch 4/30
# 86s - loss: 0.0854 - val_loss: 0.0854
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 86s - loss: 0.0862 - val_loss: 0.0861
# Epoch 2/30
# 86s - loss: 0.0861 - val_loss: 0.0862
# Epoch 3/30
# 84s - loss: 0.0861 - val_loss: 0.0860
# Epoch 4/30
# 88s - loss: 0.0861 - val_loss: 0.0860
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 86s - loss: 0.0868 - val_loss: 0.0866
# Epoch 2/30
# 86s - loss: 0.0866 - val_loss: 0.0865
# Epoch 3/30
# 88s - loss: 0.0866 - val_loss: 0.0865
# Epoch 4/30
# 84s - loss: 0.0866 - val_loss: 0.0865
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
#
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 106s - loss: 0.0803 - val_loss: 0.0799
# Epoch 2/30
# 104s - loss: 0.0799 - val_loss: 0.0797
# Epoch 3/30
# 84s - loss: 0.0799 - val_loss: 0.0797
# Epoch 4/30
# 88s - loss: 0.0799 - val_loss: 0.0796
# Epoch 5/30
# 89s - loss: 0.0798 - val_loss: 0.0798
# Epoch 6/30
# 87s - loss: 0.0798 - val_loss: 0.0796
# Epoch 7/30
# 86s - loss: 0.0798 - val_loss: 0.0797
# Train on 270000 samples, validate on 30000 samples
# Epoch 1/30
# 108s - loss: 0.0858 - val_loss: 0.0857
# Epoch 2/30
# 108s - loss: 0.0857 - val_loss: 0.0856
# Epoch 3/30
# 111s - loss: 0.0857 - val_loss: 0.0856
# Epoch 4/30
# 103s - loss: 0.0856 - val_loss: 0.0856
# predicting, mean RMSEs=0.290222
# 2
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 48s - loss: 0.0818 - val_loss: 0.0811
# Epoch 2/30
# 43s - loss: 0.0814 - val_loss: 0.0810
# Epoch 3/30
# 42s - loss: 0.0813 - val_loss: 0.0811
# Epoch 4/30
# 46s - loss: 0.0812 - val_loss: 0.0809
# Epoch 5/30
# 42s - loss: 0.0812 - val_loss: 0.0809
# Epoch 6/30
# 42s - loss: 0.0812 - val_loss: 0.0809
# Epoch 7/30
# 45s - loss: 0.0812 - val_loss: 0.0809
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 47s - loss: 0.0731 - val_loss: 0.0721
# Epoch 2/30
# 42s - loss: 0.0722 - val_loss: 0.0718
# Epoch 3/30
# 49s - loss: 0.0721 - val_loss: 0.0718
# Epoch 4/30
# 51s - loss: 0.0720 - val_loss: 0.0717
# Epoch 5/30
# 51s - loss: 0.0720 - val_loss: 0.0716
# Epoch 6/30
# 54s - loss: 0.0719 - val_loss: 0.0716
# Epoch 7/30
# 55s - loss: 0.0719 - val_loss: 0.0717
# Epoch 8/30
# 53s - loss: 0.0719 - val_loss: 0.0715
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 53s - loss: 0.0747 - val_loss: 0.0743
# Epoch 2/30
# 51s - loss: 0.0739 - val_loss: 0.0740
# Epoch 3/30
# 47s - loss: 0.0738 - val_loss: 0.0741
# Epoch 4/30
# 40s - loss: 0.0737 - val_loss: 0.0741
# Epoch 5/30
# 40s - loss: 0.0737 - val_loss: 0.0741
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 46s - loss: 0.0817 - val_loss: 0.0812
# Epoch 2/30
# 41s - loss: 0.0814 - val_loss: 0.0810
# Epoch 3/30
# 42s - loss: 0.0813 - val_loss: 0.0810
# Epoch 4/30
# 44s - loss: 0.0813 - val_loss: 0.0812
# Epoch 5/30
# 45s - loss: 0.0812 - val_loss: 0.0810
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 42s - loss: 0.0768 - val_loss: 0.0760
# Epoch 2/30
# 45s - loss: 0.0762 - val_loss: 0.0761
# Epoch 3/30
# 51s - loss: 0.0761 - val_loss: 0.0761
# Epoch 4/30
# 51s - loss: 0.0761 - val_loss: 0.0760
# ('Removing cols #', array([0]))
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 55s - loss: 0.0876 - val_loss: 0.0873
# Epoch 2/30
# 53s - loss: 0.0875 - val_loss: 0.0873
# Epoch 3/30
# 54s - loss: 0.0874 - val_loss: 0.0872
# Epoch 4/30
# 53s - loss: 0.0874 - val_loss: 0.0872
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 54s - loss: 0.0828 - val_loss: 0.0826
# Epoch 2/30
# 52s - loss: 0.0825 - val_loss: 0.0824
# Epoch 3/30
# 48s - loss: 0.0824 - val_loss: 0.0825
# Epoch 4/30
# 43s - loss: 0.0824 - val_loss: 0.0824
# Epoch 5/30
# 44s - loss: 0.0823 - val_loss: 0.0824
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 45s - loss: 0.0788 - val_loss: 0.0784
# Epoch 2/30
# 44s - loss: 0.0781 - val_loss: 0.0785
# Epoch 3/30
# 44s - loss: 0.0779 - val_loss: 0.0782
# Epoch 4/30
# 44s - loss: 0.0779 - val_loss: 0.0781
# Epoch 5/30
# 45s - loss: 0.0778 - val_loss: 0.0781
# Epoch 6/30
# 44s - loss: 0.0778 - val_loss: 0.0781
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 46s - loss: 0.0831 - val_loss: 0.0830
# Epoch 2/30
# 45s - loss: 0.0825 - val_loss: 0.0828
# Epoch 3/30
# 45s - loss: 0.0824 - val_loss: 0.0827
# Epoch 4/30
# 45s - loss: 0.0823 - val_loss: 0.0827
# Epoch 5/30
# 43s - loss: 0.0823 - val_loss: 0.0826
# Epoch 6/30
# 43s - loss: 0.0822 - val_loss: 0.0826
# Epoch 7/30
# 45s - loss: 0.0822 - val_loss: 0.0826
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 45s - loss: 0.0843 - val_loss: 0.0840
# Epoch 2/30
# 42s - loss: 0.0839 - val_loss: 0.0839
# Epoch 3/30
# 44s - loss: 0.0837 - val_loss: 0.0839
# Epoch 4/30
# 44s - loss: 0.0837 - val_loss: 0.0837
# Epoch 5/30
# 45s - loss: 0.0836 - val_loss: 0.0836
# Epoch 6/30
# 45s - loss: 0.0836 - val_loss: 0.0837
# Epoch 7/30
# 44s - loss: 0.0836 - val_loss: 0.0837
# predicting, mean RMSEs=0.281492
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 46s - loss: 0.0839 - val_loss: 0.0835
# Epoch 2/30
# 44s - loss: 0.0834 - val_loss: 0.0833
# Epoch 3/30
# 44s - loss: 0.0833 - val_loss: 0.0833
# Epoch 4/30
# 45s - loss: 0.0833 - val_loss: 0.0832
# Epoch 5/30
# 44s - loss: 0.0833 - val_loss: 0.0832
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 47s - loss: 0.0835 - val_loss: 0.0833
# Epoch 2/30
# 45s - loss: 0.0832 - val_loss: 0.0832
# Epoch 3/30
# 46s - loss: 0.0831 - val_loss: 0.0832
# Epoch 4/30
# 46s - loss: 0.0831 - val_loss: 0.0831
# Epoch 5/30
# 44s - loss: 0.0830 - val_loss: 0.0831
# Epoch 6/30
# 47s - loss: 0.0830 - val_loss: 0.0831
# Epoch 7/30
# 46s - loss: 0.0830 - val_loss: 0.0831
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 45s - loss: 0.0817 - val_loss: 0.0812
# Epoch 2/30
# 43s - loss: 0.0811 - val_loss: 0.0811
# Epoch 3/30
# 43s - loss: 0.0810 - val_loss: 0.0809
# Epoch 4/30
# 45s - loss: 0.0810 - val_loss: 0.0809
# Epoch 5/30
# 45s - loss: 0.0810 - val_loss: 0.0809
# Epoch 6/30
# 46s - loss: 0.0809 - val_loss: 0.0809
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 47s - loss: 0.0840 - val_loss: 0.0841
# Epoch 2/30
# 45s - loss: 0.0838 - val_loss: 0.0840
# Epoch 3/30
# 45s - loss: 0.0838 - val_loss: 0.0840
# Epoch 4/30
# 45s - loss: 0.0837 - val_loss: 0.0839
# Epoch 5/30
# 47s - loss: 0.0837 - val_loss: 0.0839
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 46s - loss: 0.0846 - val_loss: 0.0841
# Epoch 2/30
# 46s - loss: 0.0843 - val_loss: 0.0841
# Epoch 3/30
# 46s - loss: 0.0842 - val_loss: 0.0840
# Epoch 4/30
# 45s - loss: 0.0842 - val_loss: 0.0840
# Epoch 5/30
# 47s - loss: 0.0842 - val_loss: 0.0840
# Epoch 6/30
# 46s - loss: 0.0842 - val_loss: 0.0839
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 47s - loss: 0.0836 - val_loss: 0.0832
# Epoch 2/30
# 48s - loss: 0.0831 - val_loss: 0.0833
# Epoch 3/30
# 47s - loss: 0.0831 - val_loss: 0.0831
# Epoch 4/30
# 45s - loss: 0.0830 - val_loss: 0.0831
# Epoch 5/30
# 46s - loss: 0.0830 - val_loss: 0.0834
# Epoch 6/30
# 45s - loss: 0.0830 - val_loss: 0.0831
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 47s - loss: 0.0860 - val_loss: 0.0858
# Epoch 2/30
# 48s - loss: 0.0858 - val_loss: 0.0858
# Epoch 3/30
# 47s - loss: 0.0857 - val_loss: 0.0858
# Epoch 4/30
# 46s - loss: 0.0857 - val_loss: 0.0858
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 53s - loss: 0.0795 - val_loss: 0.0788
# Epoch 2/30
# 48s - loss: 0.0788 - val_loss: 0.0787
# Epoch 3/30
# 49s - loss: 0.0785 - val_loss: 0.0786
# Epoch 4/30
# 49s - loss: 0.0784 - val_loss: 0.0784
# Epoch 5/30
# 50s - loss: 0.0783 - val_loss: 0.0784
# Epoch 6/30
# 48s - loss: 0.0783 - val_loss: 0.0783
# Epoch 7/30
# 50s - loss: 0.0783 - val_loss: 0.0785
# Train on 135000 samples, validate on 15000 samples
# Epoch 1/30
# 55s - loss: 0.0797 - val_loss: 0.0787
# Epoch 2/30
# 53s - loss: 0.0788 - val_loss: 0.0786
# Epoch 3/30
# 52s - loss: 0.0787 - val_loss: 0.0785
# Epoch 4/30
# 50s - loss: 0.0787 - val_loss: 0.0784
# Epoch 5/30
# 46s - loss: 0.0787 - val_loss: 0.0782
# Epoch 6/30
# 47s - loss: 0.0786 - val_loss: 0.0784
# Epoch 7/30

# %% [markdown]
# # Save the RMSE's

# %%
    fName = 'results/NNMP_RMSES_Layer' + str(iLayer) + 'nRec' + str(nRecordings) + nn + '.dat'
    with open(fName,'wb') as f:
        pickle.dump(rmses, f)
    f.close()
