# %% [markdown]
# # Load Layer outputs

# %%
nn = 'NN'

import pickle
with open('results/' + nn + '_layer_outputs.dat', 'rb') as f:
    layer_outs,layer_outs_test= pickle.load(f)
f.close()

# %% [markdown]
# # Load recording and test data

# %%
import numpy as np
from keras.datasets import mnist
from scipy.misc import imresize

(Xtrain, Ytrain), (Xtest, Ytest) = mnist.load_data()

(ntrain, xdim, ydim) = Xtrain.shape
ntest = Xtest.shape[0]

# Recording data
X_pr = Xtrain[30000:60000, :, :]
Y_pr = Ytrain[30000:60000]

# downsample
factor = 1
if factor<1:
    Xtest_down = np.ones((Xtest.shape[0], int(xdim*factor), int(ydim*factor)))
    for i in range(Xtest.shape[0]):
        Xtest_down[i,:,:] = imresize(Xtest[i,:,:], factor)

    X_pr_down = np.ones((X_pr.shape[0], int(xdim*factor), int(ydim*factor)))
    for i in range(X_pr.shape[0]):
        X_pr_down[i,:,:] = imresize(X_pr[i,:,:], factor)
else:
    Xtest_down = Xtest
    X_pr_down = X_pr
    
# VECTORIZE IMAGES
Xtest_down = Xtest_down.reshape(ntest, int(xdim*factor)**2).astype('float32') / 255
X_pr_down = X_pr_down.reshape(X_pr_down.shape[0], int(xdim*factor)**2).astype('float32') / 255
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 1: GeForce GTX TITAN X (CNMeM is enabled with initial size: 50.0% of memory, cuDNN 5103)

# %% [markdown]
# # Run Neural Networks and average outputs

# %%
from copy import copy, deepcopy
from RE_PartialRecData2 import RE_PartialRecData2
from sklearn import preprocessing, linear_model
import pickle
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils
from keras.models import load_model
from keras.callbacks import EarlyStopping
from fancyimpute import SoftImpute as FI
import time

# how many recordings?
nRecordings = 10
# which layers?
layers = [0,2]
# how many iterations
nIterations = 5
# noise levels
noises = [0.20, 0.50, 1.00]

# baseline prediction error
#bl = np.std(layer_outs_test[oLayer]-np.mean(layer_outs_test[oLayer]));

oLayer = len(layer_outs)-1  # index of output layer
nOutNeurons = layer_outs[oLayer].shape[1]

for iNoise in noises:
    noise = iNoise

    for iLayer in layers:
        # how many neurons from the firs hidden layer?
        subnetSize = [2**x for x in range(np.int(np.log2(layer_outs[iLayer].shape[1])+1))]
        nSubnetSize = len(subnetSize)
        # how many samples per recording?
        nSamples = np.divide(int(X_pr_down.shape[0]/nRecordings),subnetSize)*100

        rmses = np.zeros([nIterations, nOutNeurons, nSubnetSize])
        print('Layer #', iLayer)

        for ss in range(nSubnetSize):
            print(subnetSize[ss]) 

            for it in range(nIterations):
                start = time.time()
                # copy data - is this necessary?
                layer_outputs = deepcopy(layer_outs)          

                # subsample
                X_subsample, Y_subsample = RE_PartialRecData2(layer_outputs[iLayer], layer_outputs[oLayer], 
                                                                  subnetSize[ss], nRecordings, nSamples[ss])
                # add noise (method1)
#                 sigmax = np.std(layer_outputs[iLayer],axis=0)*noise
#                 X_noise = [np.random.normal(0,sigmax[i],[X_subsample.shape[0]]) for i in range(X_subsample.shape[1])]
#                 X_noise = np.transpose(np.asarray(X_noise))
#                 X_corrupted = X_subsample + X_noise
#                 sigmay = np.std(layer_outputs[oLayer],axis=0)*noise
#                 Y_noise = [np.random.normal(0,sigmay[i],[Y_subsample.shape[0]]) for i in range(Y_subsample.shape[1])]
#                 Y_noise = np.transpose(np.asarray(Y_noise))
#                 Y_corrupted = Y_subsample + Y_noise
                
                # add noise (method2)
                X_noise = np.random.normal(0,1,X_subsample.shape)
                X_corrupted = X_subsample + np.multiply(X_noise,np.sqrt(np.absolute(X_subsample)))*noise
                Y_noise = np.random.normal(0,1,Y_subsample.shape)
                Y_corrupted = Y_subsample + np.multiply(Y_noise,np.sqrt(np.absolute(Y_subsample)))*noise

                # impute X_subsample with soft impute
                (keep_cols,) = np.where(~np.all(np.isnan(X_corrupted), axis=0))
                if ss==nSubnetSize-1:
                    X_new = X_corrupted[:,keep_cols]
                else:
                    X_new = FI(convergence_threshold=0.01, max_iters=30).complete(X_corrupted[:, keep_cols])

                X_test_new = layer_outs_test[iLayer][:, keep_cols]

                # fit ΝΝ
                model = Sequential()
                model.add(Dense(16, input_shape=(X_new.shape[1],), activation='relu'))
                model.add(Dense(16, activation='relu'))
                model.add(Dense(16, activation='relu'))                
                model.add(Dense(10, activation='softmax'))

                # Compile model
                model.compile(loss='mean_squared_error', optimizer='adam')
                callbacks = [EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=2, verbose=0)]
                model.fit(X_new, Y_corrupted, epochs=30, batch_size=16, shuffle=True, verbose=0, 
                          validation_split=0.1, callbacks=callbacks)
                stop = time.time()
                duration = stop-start
                print(duration)
                rmses[it,:,ss] = np.sqrt(np.mean((model.predict(X_test_new) - layer_outs_test[oLayer])**2, axis=0))

            print ('predicting, mean RMSEs=%f' %np.mean(rmses[it, :, ss]))


        fName = 'results/NNSI_RMSES_Layer' + str(iLayer) + '_nRec' + str(nRecordings) + '_' + nn + \
                '_Noise' + str(int(noise*100)) + '.dat'
        with open(fName,'wb') as f:
            pickle.dump(rmses, f)
        f.close()
# Out:
# ('Layer #', 0)
# 1
# [SoftImpute] Max Singular Value of X_init = 2452.479915
# [SoftImpute] Iter 1: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 2: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 3: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 4: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 5: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 6: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 7: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 8: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 9: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 10: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 11: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 12: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 13: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 14: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 15: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 16: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 17: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 18: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 19: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 20: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 21: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 22: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 23: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 24: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 25: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 26: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 27: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 28: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 29: observed MAE=0.034734 rank=10
# [SoftImpute] Iter 30: observed MAE=0.034734 rank=10
# [SoftImpute] Stopped after iteration 30 for lambda=49.049598
# 893.614818811
# [SoftImpute] Max Singular Value of X_init = 1415.884621
# [SoftImpute] Iter 1: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 2: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 3: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 4: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 5: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 6: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 7: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 8: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 9: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 10: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 11: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 12: observed MAE=0.022464 rank=10
# [SoftImpute] Iter 13: observed MAE=0.022464 rank=10
# [SoftImpute] Stopped after iteration 13 for lambda=28.317692
# 488.132897854
# [SoftImpute] Max Singular Value of X_init = 1815.159589
# [SoftImpute] Iter 1: observed MAE=0.020834 rank=8
# [SoftImpute] Iter 2: observed MAE=0.020834 rank=8
# [SoftImpute] Iter 3: observed MAE=0.020834 rank=8
# [SoftImpute] Iter 4: observed MAE=0.020834 rank=8
# [SoftImpute] Stopped after iteration 4 for lambda=36.303192
# 486.888149023
# [SoftImpute] Max Singular Value of X_init = 1280.090259
# [SoftImpute] Iter 1: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 2: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 3: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 4: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 5: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 6: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 7: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 8: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 9: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 10: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 11: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 12: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 13: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 14: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 15: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 16: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 17: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 18: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 19: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 20: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 21: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 22: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 23: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 24: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 25: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 26: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 27: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 28: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 29: observed MAE=0.015393 rank=10
# [SoftImpute] Iter 30: observed MAE=0.015393 rank=10
# [SoftImpute] Stopped after iteration 30 for lambda=25.601805
# 541.239131927
# [SoftImpute] Max Singular Value of X_init = 1574.347462
# [SoftImpute] Iter 1: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 2: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 3: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 4: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 5: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 6: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 7: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 8: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 9: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 10: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 11: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 12: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 13: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 14: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 15: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 16: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 17: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 18: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 19: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 20: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 21: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 22: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 23: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 24: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 25: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 26: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 27: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 28: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 29: observed MAE=0.024713 rank=10
# [SoftImpute] Iter 30: observed MAE=0.024713 rank=10
# [SoftImpute] Stopped after iteration 30 for lambda=31.486949
# 655.447788954
# [SoftImpute] Max Singular Value of X_init = 1697.475347
# [SoftImpute] Iter 1: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 2: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 3: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 4: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 5: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 6: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 7: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 8: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 9: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 10: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 11: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 12: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 13: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 14: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 15: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 16: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 17: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 18: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 19: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 20: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 21: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 22: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 23: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 24: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 25: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 26: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 27: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 28: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 29: observed MAE=0.019156 rank=9
# [SoftImpute] Iter 30: observed MAE=0.019156 rank=9
# [SoftImpute] Stopped after iteration 30 for lambda=33.949507
# 535.507237196
# predicting, mean RMSEs=0.284769
# 2
# [SoftImpute] Max Singular Value of X_init = 1872.111429
# [SoftImpute] Iter 1: observed MAE=0.033698 rank=19
# [SoftImpute] Iter 2: observed MAE=0.033698 rank=19
# [SoftImpute] Iter 3: observed MAE=0.033699 rank=19
# [SoftImpute] Iter 4: observed MAE=0.033700 rank=19
# [SoftImpute] Iter 5: observed MAE=0.033701 rank=19
# [SoftImpute] Iter 6: observed MAE=0.033701 rank=19
# [SoftImpute] Iter 7: observed MAE=0.033702 rank=19
# [SoftImpute] Iter 8: observed MAE=0.033702 rank=19
# [SoftImpute] Iter 9: observed MAE=0.033703 rank=19
# [SoftImpute] Iter 10: observed MAE=0.033704 rank=19
# [SoftImpute] Iter 11: observed MAE=0.033704 rank=19
# [SoftImpute] Iter 12: observed MAE=0.033705 rank=19
# [SoftImpute] Iter 13: observed MAE=0.033705 rank=19
# [SoftImpute] Iter 14: observed MAE=0.033705 rank=19
# [SoftImpute] Iter 15: observed MAE=0.033706 rank=19
# [SoftImpute] Iter 16: observed MAE=0.033706 rank=19
# [SoftImpute] Iter 17: observed MAE=0.033707 rank=19
# [SoftImpute] Iter 18: observed MAE=0.033707 rank=19
# [SoftImpute] Iter 19: observed MAE=0.033707 rank=19
# [SoftImpute] Iter 20: observed MAE=0.033708 rank=19
# [SoftImpute] Iter 21: observed MAE=0.033708 rank=19
# [SoftImpute] Iter 22: observed MAE=0.033708 rank=19
# [SoftImpute] Iter 23: observed MAE=0.033709 rank=19
# [SoftImpute] Iter 24: observed MAE=0.033709 rank=19
# [SoftImpute] Iter 25: observed MAE=0.033709 rank=19
# [SoftImpute] Iter 26: observed MAE=0.033709 rank=19
# [SoftImpute] Iter 27: observed MAE=0.033710 rank=19
# [SoftImpute] Iter 28: observed MAE=0.033710 rank=19
# [SoftImpute] Iter 29: observed MAE=0.033710 rank=19
# [SoftImpute] Iter 30: observed MAE=0.033710 rank=19
# [SoftImpute] Stopped after iteration 30 for lambda=37.442229
# 538.248537064
# [SoftImpute] Max Singular Value of X_init = 1408.165292
# [SoftImpute] Iter 1: observed MAE=0.023726 rank=17
# [SoftImpute] Iter 2: observed MAE=0.023731 rank=17
# [SoftImpute] Iter 3: observed MAE=0.023735 rank=17
# [SoftImpute] Iter 4: observed MAE=0.023739 rank=17
# [SoftImpute] Iter 5: observed MAE=0.023743 rank=17
# [SoftImpute] Iter 6: observed MAE=0.023747 rank=17
# [SoftImpute] Iter 7: observed MAE=0.023750 rank=17
# [SoftImpute] Iter 8: observed MAE=0.023754 rank=17
# [SoftImpute] Iter 9: observed MAE=0.023758 rank=17
# [SoftImpute] Iter 10: observed MAE=0.023761 rank=17
# [SoftImpute] Iter 11: observed MAE=0.023764 rank=17
# [SoftImpute] Iter 12: observed MAE=0.023767 rank=17
# [SoftImpute] Iter 13: observed MAE=0.023770 rank=17
# [SoftImpute] Iter 14: observed MAE=0.023773 rank=17
# [SoftImpute] Iter 15: observed MAE=0.023776 rank=17
# [SoftImpute] Iter 16: observed MAE=0.023779 rank=17
# [SoftImpute] Iter 17: observed MAE=0.023782 rank=17
# [SoftImpute] Iter 18: observed MAE=0.023784 rank=17
# [SoftImpute] Iter 19: observed MAE=0.023787 rank=17
# [SoftImpute] Iter 20: observed MAE=0.023789 rank=17
# [SoftImpute] Iter 21: observed MAE=0.023792 rank=17
# [SoftImpute] Iter 22: observed MAE=0.023794 rank=17
# [SoftImpute] Iter 23: observed MAE=0.023796 rank=17
# [SoftImpute] Iter 24: observed MAE=0.023798 rank=17
# [SoftImpute] Iter 25: observed MAE=0.023800 rank=17
# [SoftImpute] Iter 26: observed MAE=0.023802 rank=17
# [SoftImpute] Iter 27: observed MAE=0.023804 rank=17
# [SoftImpute] Iter 28: observed MAE=0.023806 rank=17
# [SoftImpute] Iter 29: observed MAE=0.023808 rank=17
# [SoftImpute] Iter 30: observed MAE=0.023810 rank=17
# [SoftImpute] Stopped after iteration 30 for lambda=28.163306
# 420.781306028
# [SoftImpute] Max Singular Value of X_init = 1865.200993
# [SoftImpute] Iter 1: observed MAE=0.030730 rank=17
# [SoftImpute] Iter 2: observed MAE=0.030731 rank=17
# [SoftImpute] Iter 3: observed MAE=0.030733 rank=17
# [SoftImpute] Iter 4: observed MAE=0.030734 rank=17
# [SoftImpute] Iter 5: observed MAE=0.030736 rank=17
# [SoftImpute] Iter 6: observed MAE=0.030737 rank=17
# [SoftImpute] Iter 7: observed MAE=0.030739 rank=17
# [SoftImpute] Iter 8: observed MAE=0.030740 rank=17
# [SoftImpute] Iter 9: observed MAE=0.030741 rank=17
# [SoftImpute] Iter 10: observed MAE=0.030743 rank=17
# [SoftImpute] Iter 11: observed MAE=0.030744 rank=17
# [SoftImpute] Iter 12: observed MAE=0.030745 rank=17
# [SoftImpute] Iter 13: observed MAE=0.030746 rank=17
# [SoftImpute] Iter 14: observed MAE=0.030747 rank=17
# [SoftImpute] Iter 15: observed MAE=0.030748 rank=17
# [SoftImpute] Iter 16: observed MAE=0.030749 rank=17
# [SoftImpute] Iter 17: observed MAE=0.030750 rank=17
# [SoftImpute] Iter 18: observed MAE=0.030751 rank=17
# [SoftImpute] Iter 19: observed MAE=0.030752 rank=17
# [SoftImpute] Iter 20: observed MAE=0.030753 rank=17
# [SoftImpute] Iter 21: observed MAE=0.030754 rank=17
# [SoftImpute] Iter 22: observed MAE=0.030755 rank=17
# [SoftImpute] Iter 23: observed MAE=0.030755 rank=17
# [SoftImpute] Iter 24: observed MAE=0.030756 rank=17
# [SoftImpute] Iter 25: observed MAE=0.030757 rank=17
# [SoftImpute] Iter 26: observed MAE=0.030758 rank=17
# [SoftImpute] Iter 27: observed MAE=0.030758 rank=17
# [SoftImpute] Iter 28: observed MAE=0.030759 rank=17
# [SoftImpute] Iter 29: observed MAE=0.030760 rank=17
# [SoftImpute] Iter 30: observed MAE=0.030760 rank=17
# [SoftImpute] Stopped after iteration 30 for lambda=37.304020
# 309.603747129
# [SoftImpute] Max Singular Value of X_init = 1048.161595
# [SoftImpute] Iter 1: observed MAE=0.015044 rank=17
# [SoftImpute] Iter 2: observed MAE=0.015044 rank=17
# [SoftImpute] Iter 3: observed MAE=0.015044 rank=17
# [SoftImpute] Iter 4: observed MAE=0.015045 rank=17
# [SoftImpute] Iter 5: observed MAE=0.015045 rank=17
# [SoftImpute] Iter 6: observed MAE=0.015045 rank=17
# [SoftImpute] Iter 7: observed MAE=0.015045 rank=17
# [SoftImpute] Iter 8: observed MAE=0.015046 rank=17
# [SoftImpute] Iter 9: observed MAE=0.015046 rank=17
# [SoftImpute] Iter 10: observed MAE=0.015046 rank=17
# [SoftImpute] Iter 11: observed MAE=0.015046 rank=17
# [SoftImpute] Iter 12: observed MAE=0.015046 rank=17
# [SoftImpute] Iter 13: observed MAE=0.015047 rank=17
# [SoftImpute] Iter 14: observed MAE=0.015047 rank=17
# [SoftImpute] Iter 15: observed MAE=0.015047 rank=17
# [SoftImpute] Iter 16: observed MAE=0.015047 rank=17
# [SoftImpute] Iter 17: observed MAE=0.015047 rank=17
# [SoftImpute] Iter 18: observed MAE=0.015048 rank=17
# [SoftImpute] Iter 19: observed MAE=0.015048 rank=17
# [SoftImpute] Iter 20: observed MAE=0.015048 rank=17
# [SoftImpute] Iter 21: observed MAE=0.015048 rank=17
# [SoftImpute] Iter 22: observed MAE=0.015048 rank=17
# [SoftImpute] Iter 23: observed MAE=0.015048 rank=17
# [SoftImpute] Iter 24: observed MAE=0.015048 rank=17
# [SoftImpute] Iter 25: observed MAE=0.015049 rank=17
# [SoftImpute] Iter 26: observed MAE=0.015049 rank=17
# [SoftImpute] Iter 27: observed MAE=0.015049 rank=17
# [SoftImpute] Iter 28: observed MAE=0.015049 rank=17
# [SoftImpute] Iter 29: observed MAE=0.015049 rank=17
# [SoftImpute] Iter 30: observed MAE=0.015049 rank=17
# [SoftImpute] Stopped after iteration 30 for lambda=20.963232
# 395.79156208
# [SoftImpute] Max Singular Value of X_init = 1362.280575
# [SoftImpute] Iter 1: observed MAE=0.022007 rank=18
# [SoftImpute] Iter 2: observed MAE=0.022011 rank=18
# [SoftImpute] Iter 3: observed MAE=0.022014 rank=18
# [SoftImpute] Iter 4: observed MAE=0.022018 rank=18
# [SoftImpute] Iter 5: observed MAE=0.022021 rank=18
# [SoftImpute] Iter 6: observed MAE=0.022024 rank=18
# [SoftImpute] Iter 7: observed MAE=0.022027 rank=18
# [SoftImpute] Iter 8: observed MAE=0.022030 rank=18
# [SoftImpute] Iter 9: observed MAE=0.022033 rank=18
# [SoftImpute] Iter 10: observed MAE=0.022035 rank=18
# [SoftImpute] Iter 11: observed MAE=0.022038 rank=18
# [SoftImpute] Iter 12: observed MAE=0.022040 rank=18
# [SoftImpute] Iter 13: observed MAE=0.022042 rank=18
# [SoftImpute] Iter 14: observed MAE=0.022045 rank=18
# [SoftImpute] Iter 15: observed MAE=0.022047 rank=18
# [SoftImpute] Iter 16: observed MAE=0.022049 rank=18
# [SoftImpute] Iter 17: observed MAE=0.022050 rank=18
# [SoftImpute] Iter 18: observed MAE=0.022052 rank=18
# [SoftImpute] Iter 19: observed MAE=0.022054 rank=18
# [SoftImpute] Iter 20: observed MAE=0.022056 rank=18
# [SoftImpute] Iter 21: observed MAE=0.022057 rank=18
# [SoftImpute] Iter 22: observed MAE=0.022059 rank=18
# [SoftImpute] Iter 23: observed MAE=0.022060 rank=18
# [SoftImpute] Iter 24: observed MAE=0.022062 rank=18
# [SoftImpute] Iter 25: observed MAE=0.022063 rank=18
# [SoftImpute] Iter 26: observed MAE=0.022064 rank=18
# [SoftImpute] Iter 27: observed MAE=0.022065 rank=18
# [SoftImpute] Iter 28: observed MAE=0.022066 rank=18
# [SoftImpute] Iter 29: observed MAE=0.022068 rank=18
# [SoftImpute] Iter 30: observed MAE=0.022069 rank=18
# [SoftImpute] Stopped after iteration 30 for lambda=27.245611
# 329.608833075
# predicting, mean RMSEs=0.263366
# 4
# [SoftImpute] Max Singular Value of X_init = 1067.212679
# [SoftImpute] Iter 1: observed MAE=0.029103 rank=37
# [SoftImpute] Iter 2: observed MAE=0.029109 rank=37
# [SoftImpute] Iter 3: observed MAE=0.029115 rank=37
# [SoftImpute] Iter 4: observed MAE=0.029121 rank=37
# [SoftImpute] Iter 5: observed MAE=0.029126 rank=37
# [SoftImpute] Iter 6: observed MAE=0.029132 rank=37
# [SoftImpute] Iter 7: observed MAE=0.029137 rank=37
# [SoftImpute] Iter 8: observed MAE=0.029142 rank=37
# [SoftImpute] Iter 9: observed MAE=0.029146 rank=37
# [SoftImpute] Iter 10: observed MAE=0.029151 rank=37
# [SoftImpute] Iter 11: observed MAE=0.029155 rank=37
# [SoftImpute] Iter 12: observed MAE=0.029159 rank=37
# [SoftImpute] Iter 13: observed MAE=0.029163 rank=37
# [SoftImpute] Iter 14: observed MAE=0.029167 rank=37
# [SoftImpute] Iter 15: observed MAE=0.029170 rank=37
# [SoftImpute] Iter 16: observed MAE=0.029174 rank=37
# [SoftImpute] Iter 17: observed MAE=0.029177 rank=37
# [SoftImpute] Iter 18: observed MAE=0.029181 rank=37
# [SoftImpute] Iter 19: observed MAE=0.029184 rank=37
# [SoftImpute] Iter 20: observed MAE=0.029187 rank=37
# [SoftImpute] Iter 21: observed MAE=0.029190 rank=37
# [SoftImpute] Iter 22: observed MAE=0.029193 rank=37
# [SoftImpute] Iter 23: observed MAE=0.029195 rank=37
# [SoftImpute] Iter 24: observed MAE=0.029198 rank=37
# [SoftImpute] Iter 25: observed MAE=0.029201 rank=37
# [SoftImpute] Iter 26: observed MAE=0.029203 rank=37
# [SoftImpute] Iter 27: observed MAE=0.029205 rank=37
# [SoftImpute] Iter 28: observed MAE=0.029208 rank=37
# [SoftImpute] Iter 29: observed MAE=0.029210 rank=37
# [SoftImpute] Iter 30: observed MAE=0.029212 rank=37
# [SoftImpute] Stopped after iteration 30 for lambda=21.344254
# 285.614570141
# [SoftImpute] Max Singular Value of X_init = 1332.181222
# [SoftImpute] Iter 1: observed MAE=0.032512 rank=34
# [SoftImpute] Iter 2: observed MAE=0.032521 rank=34
# [SoftImpute] Iter 3: observed MAE=0.032530 rank=34
# [SoftImpute] Iter 4: observed MAE=0.032539 rank=34
# [SoftImpute] Iter 5: observed MAE=0.032547 rank=34
# [SoftImpute] Iter 6: observed MAE=0.032555 rank=34
# [SoftImpute] Iter 7: observed MAE=0.032563 rank=34
# [SoftImpute] Iter 8: observed MAE=0.032570 rank=34
# [SoftImpute] Iter 9: observed MAE=0.032577 rank=34
# [SoftImpute] Iter 10: observed MAE=0.032583 rank=34
# [SoftImpute] Iter 11: observed MAE=0.032589 rank=34
# [SoftImpute] Iter 12: observed MAE=0.032595 rank=34
# [SoftImpute] Iter 13: observed MAE=0.032601 rank=34
# [SoftImpute] Iter 14: observed MAE=0.032606 rank=34
# [SoftImpute] Iter 15: observed MAE=0.032612 rank=34
# [SoftImpute] Iter 16: observed MAE=0.032617 rank=34
# [SoftImpute] Iter 17: observed MAE=0.032621 rank=34
# [SoftImpute] Iter 18: observed MAE=0.032626 rank=34
# [SoftImpute] Iter 19: observed MAE=0.032630 rank=34
# [SoftImpute] Iter 20: observed MAE=0.032635 rank=34
# [SoftImpute] Iter 21: observed MAE=0.032639 rank=34
# [SoftImpute] Iter 22: observed MAE=0.032642 rank=34
# [SoftImpute] Iter 23: observed MAE=0.032646 rank=34
# [SoftImpute] Iter 24: observed MAE=0.032650 rank=34
# [SoftImpute] Iter 25: observed MAE=0.032653 rank=34
# [SoftImpute] Iter 26: observed MAE=0.032656 rank=34
# [SoftImpute] Iter 27: observed MAE=0.032659 rank=34
# [SoftImpute] Iter 28: observed MAE=0.032662 rank=34
# [SoftImpute] Iter 29: observed MAE=0.032665 rank=34
# [SoftImpute] Iter 30: observed MAE=0.032668 rank=34
# [SoftImpute] Stopped after iteration 30 for lambda=26.643624
# 193.494542122
# [SoftImpute] Max Singular Value of X_init = 1139.955538
# [SoftImpute] Iter 1: observed MAE=0.029600 rank=34
# [SoftImpute] Iter 2: observed MAE=0.029610 rank=34
# [SoftImpute] Iter 3: observed MAE=0.029619 rank=34
# [SoftImpute] Iter 4: observed MAE=0.029628 rank=34
# [SoftImpute] Iter 5: observed MAE=0.029637 rank=34
# [SoftImpute] Iter 6: observed MAE=0.029645 rank=34
# [SoftImpute] Iter 7: observed MAE=0.029653 rank=34
# [SoftImpute] Iter 8: observed MAE=0.029660 rank=34
# [SoftImpute] Iter 9: observed MAE=0.029667 rank=34
# [SoftImpute] Iter 10: observed MAE=0.029674 rank=34
# [SoftImpute] Iter 11: observed MAE=0.029681 rank=34
# [SoftImpute] Iter 12: observed MAE=0.029687 rank=34
# [SoftImpute] Iter 13: observed MAE=0.029693 rank=34
# [SoftImpute] Iter 14: observed MAE=0.029699 rank=34
# [SoftImpute] Iter 15: observed MAE=0.029705 rank=34
# [SoftImpute] Iter 16: observed MAE=0.029710 rank=34
# [SoftImpute] Iter 17: observed MAE=0.029716 rank=34
# [SoftImpute] Iter 18: observed MAE=0.029721 rank=34
# [SoftImpute] Iter 19: observed MAE=0.029725 rank=34
# [SoftImpute] Iter 20: observed MAE=0.029730 rank=34
# [SoftImpute] Iter 21: observed MAE=0.029734 rank=34
# [SoftImpute] Iter 22: observed MAE=0.029739 rank=34
# [SoftImpute] Iter 23: observed MAE=0.029743 rank=34
# [SoftImpute] Iter 24: observed MAE=0.029747 rank=34
# [SoftImpute] Iter 25: observed MAE=0.029751 rank=34
# [SoftImpute] Iter 26: observed MAE=0.029754 rank=34
# [SoftImpute] Iter 27: observed MAE=0.029758 rank=34
# [SoftImpute] Iter 28: observed MAE=0.029761 rank=34
# [SoftImpute] Iter 29: observed MAE=0.029765 rank=34
# [SoftImpute] Iter 30: observed MAE=0.029768 rank=34
# [SoftImpute] Stopped after iteration 30 for lambda=22.799111
# 194.472699881
# [SoftImpute] Max Singular Value of X_init = 1321.376226
# [SoftImpute] Iter 1: observed MAE=0.034635 rank=32
# [SoftImpute] Iter 2: observed MAE=0.034656 rank=32
# [SoftImpute] Iter 3: observed MAE=0.034676 rank=32
# [SoftImpute] Iter 4: observed MAE=0.034696 rank=32
# [SoftImpute] Iter 5: observed MAE=0.034715 rank=32
# [SoftImpute] Iter 6: observed MAE=0.034733 rank=32
# [SoftImpute] Iter 7: observed MAE=0.034750 rank=32
# [SoftImpute] Iter 8: observed MAE=0.034767 rank=32
# [SoftImpute] Iter 9: observed MAE=0.034783 rank=32
# [SoftImpute] Iter 10: observed MAE=0.034799 rank=32
# [SoftImpute] Iter 11: observed MAE=0.034814 rank=32
# [SoftImpute] Iter 12: observed MAE=0.034829 rank=32
# [SoftImpute] Iter 13: observed MAE=0.034843 rank=32
# [SoftImpute] Iter 14: observed MAE=0.034857 rank=32
# [SoftImpute] Iter 15: observed MAE=0.034870 rank=32
# [SoftImpute] Iter 16: observed MAE=0.034883 rank=32
# [SoftImpute] Iter 17: observed MAE=0.034895 rank=32
# [SoftImpute] Iter 18: observed MAE=0.034907 rank=32
# [SoftImpute] Iter 19: observed MAE=0.034918 rank=32
# [SoftImpute] Iter 20: observed MAE=0.034929 rank=32
# [SoftImpute] Iter 21: observed MAE=0.034940 rank=32
# [SoftImpute] Iter 22: observed MAE=0.034950 rank=32
# [SoftImpute] Iter 23: observed MAE=0.034960 rank=32
# [SoftImpute] Iter 24: observed MAE=0.034970 rank=32
# [SoftImpute] Iter 25: observed MAE=0.034979 rank=32
# [SoftImpute] Iter 26: observed MAE=0.034988 rank=32
# [SoftImpute] Iter 27: observed MAE=0.034996 rank=32
# [SoftImpute] Iter 28: observed MAE=0.035005 rank=32
# [SoftImpute] Iter 29: observed MAE=0.035013 rank=32
# [SoftImpute] Iter 30: observed MAE=0.035021 rank=32
# [SoftImpute] Stopped after iteration 30 for lambda=26.427525
# 351.026207924
# [SoftImpute] Max Singular Value of X_init = 1210.524856
# [SoftImpute] Iter 1: observed MAE=0.028203 rank=30
# [SoftImpute] Iter 2: observed MAE=0.028222 rank=30
# [SoftImpute] Iter 3: observed MAE=0.028241 rank=30
# [SoftImpute] Iter 4: observed MAE=0.028258 rank=30
# [SoftImpute] Iter 5: observed MAE=0.028275 rank=30
# [SoftImpute] Iter 6: observed MAE=0.028292 rank=30
# [SoftImpute] Iter 7: observed MAE=0.028307 rank=30
# [SoftImpute] Iter 8: observed MAE=0.028323 rank=30
# [SoftImpute] Iter 9: observed MAE=0.028337 rank=30
# [SoftImpute] Iter 10: observed MAE=0.028351 rank=30
# [SoftImpute] Iter 11: observed MAE=0.028365 rank=30
# [SoftImpute] Iter 12: observed MAE=0.028378 rank=30
# [SoftImpute] Iter 13: observed MAE=0.028390 rank=30
# [SoftImpute] Iter 14: observed MAE=0.028402 rank=30
# [SoftImpute] Iter 15: observed MAE=0.028414 rank=30
# [SoftImpute] Iter 16: observed MAE=0.028425 rank=30
# [SoftImpute] Iter 17: observed MAE=0.028436 rank=30
# [SoftImpute] Iter 18: observed MAE=0.028446 rank=30
# [SoftImpute] Iter 19: observed MAE=0.028456 rank=30
# [SoftImpute] Iter 20: observed MAE=0.028466 rank=30
# [SoftImpute] Iter 21: observed MAE=0.028475 rank=30
# [SoftImpute] Iter 22: observed MAE=0.028484 rank=30
# [SoftImpute] Iter 23: observed MAE=0.028493 rank=30
# [SoftImpute] Iter 24: observed MAE=0.028501 rank=30
# [SoftImpute] Iter 25: observed MAE=0.028509 rank=30
# [SoftImpute] Iter 26: observed MAE=0.028517 rank=30
# [SoftImpute] Iter 27: observed MAE=0.028525 rank=30
# [SoftImpute] Iter 28: observed MAE=0.028532 rank=30
# [SoftImpute] Iter 29: observed MAE=0.028539 rank=30
# [SoftImpute] Iter 30: observed MAE=0.028546 rank=30
# [SoftImpute] Stopped after iteration 30 for lambda=24.210497
# 262.178722858
# predicting, mean RMSEs=0.277224
# 8
# [SoftImpute] Max Singular Value of X_init = 1270.333462
# [SoftImpute] Iter 1: observed MAE=0.044719 rank=59
# [SoftImpute] Iter 2: observed MAE=0.044788 rank=59
# [SoftImpute] Iter 3: observed MAE=0.044853 rank=59
# [SoftImpute] Iter 4: observed MAE=0.044914 rank=59
# [SoftImpute] Iter 5: observed MAE=0.044971 rank=59
# [SoftImpute] Iter 6: observed MAE=0.045024 rank=59
# [SoftImpute] Iter 7: observed MAE=0.045075 rank=59
# [SoftImpute] Iter 8: observed MAE=0.045122 rank=59
# [SoftImpute] Iter 9: observed MAE=0.045167 rank=59
# [SoftImpute] Iter 10: observed MAE=0.045210 rank=59
# [SoftImpute] Iter 11: observed MAE=0.045250 rank=59
# [SoftImpute] Iter 12: observed MAE=0.045287 rank=59
# [SoftImpute] Iter 13: observed MAE=0.045323 rank=59
# [SoftImpute] Iter 14: observed MAE=0.045357 rank=59
# [SoftImpute] Iter 15: observed MAE=0.045390 rank=59
# [SoftImpute] Iter 16: observed MAE=0.045420 rank=59
# [SoftImpute] Iter 17: observed MAE=0.045450 rank=59
# [SoftImpute] Iter 18: observed MAE=0.045477 rank=59
# [SoftImpute] Iter 19: observed MAE=0.045504 rank=59
# [SoftImpute] Iter 20: observed MAE=0.045529 rank=59
# [SoftImpute] Iter 21: observed MAE=0.045553 rank=59
# [SoftImpute] Iter 22: observed MAE=0.045577 rank=59
# [SoftImpute] Iter 23: observed MAE=0.045599 rank=59
# [SoftImpute] Iter 24: observed MAE=0.045620 rank=59
# [SoftImpute] Iter 25: observed MAE=0.045640 rank=59
# [SoftImpute] Iter 26: observed MAE=0.045660 rank=59
# [SoftImpute] Iter 27: observed MAE=0.045678 rank=59
# [SoftImpute] Iter 28: observed MAE=0.045696 rank=59
# [SoftImpute] Iter 29: observed MAE=0.045713 rank=59
# [SoftImpute] Iter 30: observed MAE=0.045730 rank=59
# [SoftImpute] Stopped after iteration 30 for lambda=25.406669
# 137.545498848
# [SoftImpute] Max Singular Value of X_init = 958.970098
# [SoftImpute] Iter 1: observed MAE=0.033284 rank=64
# [SoftImpute] Iter 2: observed MAE=0.033306 rank=64
# [SoftImpute] Iter 3: observed MAE=0.033327 rank=64
# [SoftImpute] Iter 4: observed MAE=0.033348 rank=64
# [SoftImpute] Iter 5: observed MAE=0.033367 rank=64
# [SoftImpute] Iter 6: observed MAE=0.033386 rank=64
# [SoftImpute] Iter 7: observed MAE=0.033404 rank=64
# [SoftImpute] Iter 8: observed MAE=0.033421 rank=64
# [SoftImpute] Iter 9: observed MAE=0.033438 rank=64
# [SoftImpute] Iter 10: observed MAE=0.033453 rank=64
# [SoftImpute] Iter 11: observed MAE=0.033468 rank=64
# [SoftImpute] Iter 12: observed MAE=0.033483 rank=64
# [SoftImpute] Iter 13: observed MAE=0.033497 rank=64
# [SoftImpute] Iter 14: observed MAE=0.033510 rank=64
# [SoftImpute] Iter 15: observed MAE=0.033523 rank=64
# [SoftImpute] Iter 16: observed MAE=0.033536 rank=64
# [SoftImpute] Iter 17: observed MAE=0.033548 rank=64
# [SoftImpute] Iter 18: observed MAE=0.033559 rank=64
# [SoftImpute] Iter 19: observed MAE=0.033570 rank=64
# [SoftImpute] Iter 20: observed MAE=0.033581 rank=64
# [SoftImpute] Iter 21: observed MAE=0.033592 rank=64
# [SoftImpute] Iter 22: observed MAE=0.033602 rank=64
# [SoftImpute] Iter 23: observed MAE=0.033611 rank=64
# [SoftImpute] Iter 24: observed MAE=0.033621 rank=64
# [SoftImpute] Iter 25: observed MAE=0.033630 rank=64
# [SoftImpute] Iter 26: observed MAE=0.033638 rank=64
# [SoftImpute] Iter 27: observed MAE=0.033647 rank=64
# [SoftImpute] Iter 28: observed MAE=0.033655 rank=64
# [SoftImpute] Iter 29: observed MAE=0.033663 rank=64
# [SoftImpute] Iter 30: observed MAE=0.033670 rank=64
# [SoftImpute] Stopped after iteration 30 for lambda=19.179402
# 144.40810585
# [SoftImpute] Max Singular Value of X_init = 890.801153
# [SoftImpute] Iter 1: observed MAE=0.031271 rank=57
# [SoftImpute] Iter 2: observed MAE=0.031295 rank=57
# [SoftImpute] Iter 3: observed MAE=0.031318 rank=57
# [SoftImpute] Iter 4: observed MAE=0.031340 rank=57
# [SoftImpute] Iter 5: observed MAE=0.031361 rank=57
# [SoftImpute] Iter 6: observed MAE=0.031382 rank=57
# [SoftImpute] Iter 7: observed MAE=0.031401 rank=57
# [SoftImpute] Iter 8: observed MAE=0.031420 rank=57
# [SoftImpute] Iter 9: observed MAE=0.031438 rank=57
# [SoftImpute] Iter 10: observed MAE=0.031455 rank=57
# [SoftImpute] Iter 11: observed MAE=0.031471 rank=57
# [SoftImpute] Iter 12: observed MAE=0.031487 rank=57
# [SoftImpute] Iter 13: observed MAE=0.031502 rank=57
# [SoftImpute] Iter 14: observed MAE=0.031517 rank=57
# [SoftImpute] Iter 15: observed MAE=0.031531 rank=57
# [SoftImpute] Iter 16: observed MAE=0.031545 rank=57
# [SoftImpute] Iter 17: observed MAE=0.031558 rank=57
# [SoftImpute] Iter 18: observed MAE=0.031571 rank=57
# [SoftImpute] Iter 19: observed MAE=0.031583 rank=57
# [SoftImpute] Iter 20: observed MAE=0.031595 rank=57
# [SoftImpute] Iter 21: observed MAE=0.031606 rank=57
# [SoftImpute] Iter 22: observed MAE=0.031617 rank=57
# [SoftImpute] Iter 23: observed MAE=0.031628 rank=57
# [SoftImpute] Iter 24: observed MAE=0.031638 rank=57
# [SoftImpute] Iter 25: observed MAE=0.031648 rank=57
# [SoftImpute] Iter 26: observed MAE=0.031658 rank=57
# [SoftImpute] Iter 27: observed MAE=0.031667 rank=57
# [SoftImpute] Iter 28: observed MAE=0.031676 rank=57
# [SoftImpute] Iter 29: observed MAE=0.031685 rank=57
# [SoftImpute] Iter 30: observed MAE=0.031693 rank=57
# [SoftImpute] Stopped after iteration 30 for lambda=17.816023
# 134.294080019
# [SoftImpute] Max Singular Value of X_init = 1197.339138
# [SoftImpute] Iter 1: observed MAE=0.038685 rank=54
# [SoftImpute] Iter 2: observed MAE=0.038747 rank=54
# [SoftImpute] Iter 3: observed MAE=0.038805 rank=54
# [SoftImpute] Iter 4: observed MAE=0.038860 rank=54
# [SoftImpute] Iter 5: observed MAE=0.038912 rank=54
# [SoftImpute] Iter 6: observed MAE=0.038961 rank=54
# [SoftImpute] Iter 7: observed MAE=0.039008 rank=54
# [SoftImpute] Iter 8: observed MAE=0.039052 rank=54
# [SoftImpute] Iter 9: observed MAE=0.039094 rank=54
# [SoftImpute] Iter 10: observed MAE=0.039134 rank=54
# [SoftImpute] Iter 11: observed MAE=0.039172 rank=54
# [SoftImpute] Iter 12: observed MAE=0.039208 rank=54
# [SoftImpute] Iter 13: observed MAE=0.039242 rank=54
# [SoftImpute] Iter 14: observed MAE=0.039275 rank=54
# [SoftImpute] Iter 15: observed MAE=0.039306 rank=54
# [SoftImpute] Iter 16: observed MAE=0.039336 rank=54
# [SoftImpute] Iter 17: observed MAE=0.039364 rank=54
# [SoftImpute] Iter 18: observed MAE=0.039391 rank=54
# [SoftImpute] Iter 19: observed MAE=0.039417 rank=54
# [SoftImpute] Iter 20: observed MAE=0.039442 rank=54
# [SoftImpute] Iter 21: observed MAE=0.039466 rank=54
# [SoftImpute] Iter 22: observed MAE=0.039489 rank=54
# [SoftImpute] Iter 23: observed MAE=0.039511 rank=54
# [SoftImpute] Iter 24: observed MAE=0.039532 rank=54
# [SoftImpute] Iter 25: observed MAE=0.039552 rank=54
# [SoftImpute] Iter 26: observed MAE=0.039572 rank=54
# [SoftImpute] Iter 27: observed MAE=0.039590 rank=54
# [SoftImpute] Iter 28: observed MAE=0.039608 rank=54
# [SoftImpute] Iter 29: observed MAE=0.039626 rank=54
# [SoftImpute] Iter 30: observed MAE=0.039642 rank=54
# [SoftImpute] Stopped after iteration 30 for lambda=23.946783
# 158.969554901
# [SoftImpute] Max Singular Value of X_init = 1438.313698
# [SoftImpute] Iter 1: observed MAE=0.053399 rank=59
# [SoftImpute] Iter 2: observed MAE=0.053457 rank=59
# [SoftImpute] Iter 3: observed MAE=0.053513 rank=59
# [SoftImpute] Iter 4: observed MAE=0.053565 rank=59
# [SoftImpute] Iter 5: observed MAE=0.053616 rank=59
# [SoftImpute] Iter 6: observed MAE=0.053663 rank=59
# [SoftImpute] Iter 7: observed MAE=0.053709 rank=59
# [SoftImpute] Iter 8: observed MAE=0.053752 rank=59
# [SoftImpute] Iter 9: observed MAE=0.053793 rank=59
# [SoftImpute] Iter 10: observed MAE=0.053833 rank=59
# [SoftImpute] Iter 11: observed MAE=0.053870 rank=59
# [SoftImpute] Iter 12: observed MAE=0.053906 rank=59
# [SoftImpute] Iter 13: observed MAE=0.053940 rank=59
# [SoftImpute] Iter 14: observed MAE=0.053973 rank=59
# [SoftImpute] Iter 15: observed MAE=0.054004 rank=59
# [SoftImpute] Iter 16: observed MAE=0.054034 rank=59
# [SoftImpute] Iter 17: observed MAE=0.054063 rank=59
# [SoftImpute] Iter 18: observed MAE=0.054090 rank=59
# [SoftImpute] Iter 19: observed MAE=0.054117 rank=59
# [SoftImpute] Iter 20: observed MAE=0.054142 rank=59
# [SoftImpute] Iter 21: observed MAE=0.054166 rank=59
# [SoftImpute] Iter 22: observed MAE=0.054189 rank=59
# [SoftImpute] Iter 23: observed MAE=0.054212 rank=59
# [SoftImpute] Iter 24: observed MAE=0.054233 rank=59
# [SoftImpute] Iter 25: observed MAE=0.054253 rank=59
# [SoftImpute] Iter 26: observed MAE=0.054273 rank=59
# [SoftImpute] Iter 27: observed MAE=0.054292 rank=59
# [SoftImpute] Iter 28: observed MAE=0.054311 rank=59
# [SoftImpute] Iter 29: observed MAE=0.054328 rank=59
# [SoftImpute] Iter 30: observed MAE=0.054345 rank=59
# [SoftImpute] Stopped after iteration 30 for lambda=28.766274
# 136.805580854
# predicting, mean RMSEs=0.224493
# 16
# [SoftImpute] Max Singular Value of X_init = 1170.736517
# [SoftImpute] Iter 1: observed MAE=0.053868 rank=98
# [SoftImpute] Iter 2: observed MAE=0.054010 rank=98
# [SoftImpute] Iter 3: observed MAE=0.054143 rank=98
# [SoftImpute] Iter 4: observed MAE=0.054267 rank=98
# [SoftImpute] Iter 5: observed MAE=0.054383 rank=98
# [SoftImpute] Iter 6: observed MAE=0.054492 rank=98
# [SoftImpute] Iter 7: observed MAE=0.054594 rank=98
# [SoftImpute] Iter 8: observed MAE=0.054690 rank=98
# [SoftImpute] Iter 9: observed MAE=0.054780 rank=98
# [SoftImpute] Iter 10: observed MAE=0.054865 rank=98
# [SoftImpute] Iter 11: observed MAE=0.054946 rank=98
# [SoftImpute] Iter 12: observed MAE=0.055022 rank=98
# [SoftImpute] Iter 13: observed MAE=0.055094 rank=98
# [SoftImpute] Iter 14: observed MAE=0.055162 rank=98
# [SoftImpute] Iter 15: observed MAE=0.055227 rank=98
# [SoftImpute] Iter 16: observed MAE=0.055288 rank=98
# [SoftImpute] Iter 17: observed MAE=0.055347 rank=98
# [SoftImpute] Iter 18: observed MAE=0.055402 rank=98
# [SoftImpute] Iter 19: observed MAE=0.055455 rank=98
# [SoftImpute] Iter 20: observed MAE=0.055506 rank=98
# [SoftImpute] Iter 21: observed MAE=0.055554 rank=98
# [SoftImpute] Iter 22: observed MAE=0.055600 rank=98
# [SoftImpute] Iter 23: observed MAE=0.055644 rank=98
# [SoftImpute] Iter 24: observed MAE=0.055686 rank=98
# [SoftImpute] Iter 25: observed MAE=0.055726 rank=98
# [SoftImpute] Iter 26: observed MAE=0.055764 rank=98
# [SoftImpute] Iter 27: observed MAE=0.055801 rank=98
# [SoftImpute] Iter 28: observed MAE=0.055837 rank=98
# [SoftImpute] Iter 29: observed MAE=0.055870 rank=98
# [SoftImpute] Iter 30: observed MAE=0.055903 rank=98
# [SoftImpute] Stopped after iteration 30 for lambda=23.414730
# 151.791784048
# [SoftImpute] Max Singular Value of X_init = 832.339305
# [SoftImpute] Iter 1: observed MAE=0.036602 rank=90
# [SoftImpute] Iter 2: observed MAE=0.036676 rank=90
# [SoftImpute] Iter 3: observed MAE=0.036745 rank=90
# [SoftImpute] Iter 4: observed MAE=0.036812 rank=90
# [SoftImpute] Iter 5: observed MAE=0.036876 rank=90
# [SoftImpute] Iter 6: observed MAE=0.036936 rank=90
# [SoftImpute] Iter 7: observed MAE=0.036994 rank=90
# [SoftImpute] Iter 8: observed MAE=0.037050 rank=90
# [SoftImpute] Iter 9: observed MAE=0.037103 rank=90
# [SoftImpute] Iter 10: observed MAE=0.037153 rank=90
# [SoftImpute] Iter 11: observed MAE=0.037202 rank=90
# [SoftImpute] Iter 12: observed MAE=0.037248 rank=90
# [SoftImpute] Iter 13: observed MAE=0.037292 rank=90
# [SoftImpute] Iter 14: observed MAE=0.037335 rank=90
# [SoftImpute] Iter 15: observed MAE=0.037376 rank=90
# [SoftImpute] Iter 16: observed MAE=0.037415 rank=90
# [SoftImpute] Iter 17: observed MAE=0.037453 rank=90
# [SoftImpute] Iter 18: observed MAE=0.037489 rank=90
# [SoftImpute] Iter 19: observed MAE=0.037524 rank=90
# [SoftImpute] Iter 20: observed MAE=0.037558 rank=90
# [SoftImpute] Iter 21: observed MAE=0.037590 rank=90
# [SoftImpute] Iter 22: observed MAE=0.037621 rank=90
# [SoftImpute] Iter 23: observed MAE=0.037651 rank=90
# [SoftImpute] Iter 24: observed MAE=0.037680 rank=90
# [SoftImpute] Iter 25: observed MAE=0.037709 rank=90
# [SoftImpute] Iter 26: observed MAE=0.037736 rank=90
# [SoftImpute] Iter 27: observed MAE=0.037762 rank=90
# [SoftImpute] Iter 28: observed MAE=0.037787 rank=90
# [SoftImpute] Iter 29: observed MAE=0.037811 rank=90
# [SoftImpute] Iter 30: observed MAE=0.037835 rank=90
# [SoftImpute] Stopped after iteration 30 for lambda=16.646786
# 122.797787905
# [SoftImpute] Max Singular Value of X_init = 896.733600
# [SoftImpute] Iter 1: observed MAE=0.038057 rank=83
# [SoftImpute] Iter 2: observed MAE=0.038146 rank=83
# [SoftImpute] Iter 3: observed MAE=0.038232 rank=83
# [SoftImpute] Iter 4: observed MAE=0.038313 rank=83
# [SoftImpute] Iter 5: observed MAE=0.038390 rank=83
# [SoftImpute] Iter 6: observed MAE=0.038463 rank=83
# [SoftImpute] Iter 7: observed MAE=0.038533 rank=83
# [SoftImpute] Iter 8: observed MAE=0.038600 rank=83
# [SoftImpute] Iter 9: observed MAE=0.038663 rank=83
# [SoftImpute] Iter 10: observed MAE=0.038725 rank=83
# [SoftImpute] Iter 11: observed MAE=0.038783 rank=83
# [SoftImpute] Iter 12: observed MAE=0.038839 rank=83
# [SoftImpute] Iter 13: observed MAE=0.038893 rank=83
# [SoftImpute] Iter 14: observed MAE=0.038945 rank=83
# [SoftImpute] Iter 15: observed MAE=0.038994 rank=83
# [SoftImpute] Iter 16: observed MAE=0.039042 rank=83
# [SoftImpute] Iter 17: observed MAE=0.039088 rank=83
# [SoftImpute] Iter 18: observed MAE=0.039133 rank=83
# [SoftImpute] Iter 19: observed MAE=0.039176 rank=83
# [SoftImpute] Iter 20: observed MAE=0.039217 rank=83
# [SoftImpute] Iter 21: observed MAE=0.039257 rank=83
# [SoftImpute] Iter 22: observed MAE=0.039295 rank=83
# [SoftImpute] Iter 23: observed MAE=0.039332 rank=83
# [SoftImpute] Iter 24: observed MAE=0.039368 rank=83
# [SoftImpute] Iter 25: observed MAE=0.039403 rank=83
# [SoftImpute] Iter 26: observed MAE=0.039437 rank=83
# [SoftImpute] Iter 27: observed MAE=0.039469 rank=83
# [SoftImpute] Iter 28: observed MAE=0.039501 rank=83
# [SoftImpute] Iter 29: observed MAE=0.039531 rank=83
# [SoftImpute] Iter 30: observed MAE=0.039561 rank=83
# [SoftImpute] Stopped after iteration 30 for lambda=17.934672
# 105.243085861
# [SoftImpute] Max Singular Value of X_init = 1041.496835
# [SoftImpute] Iter 1: observed MAE=0.047523 rank=94
# [SoftImpute] Iter 2: observed MAE=0.047633 rank=94
# [SoftImpute] Iter 3: observed MAE=0.047737 rank=94
# [SoftImpute] Iter 4: observed MAE=0.047836 rank=94
# [SoftImpute] Iter 5: observed MAE=0.047929 rank=94
# [SoftImpute] Iter 6: observed MAE=0.048017 rank=94
# [SoftImpute] Iter 7: observed MAE=0.048100 rank=94
# [SoftImpute] Iter 8: observed MAE=0.048179 rank=94
# [SoftImpute] Iter 9: observed MAE=0.048254 rank=94
# [SoftImpute] Iter 10: observed MAE=0.048325 rank=94
# [SoftImpute] Iter 11: observed MAE=0.048393 rank=94
# [SoftImpute] Iter 12: observed MAE=0.048457 rank=94
# [SoftImpute] Iter 13: observed MAE=0.048518 rank=94
# [SoftImpute] Iter 14: observed MAE=0.048576 rank=94
# [SoftImpute] Iter 15: observed MAE=0.048631 rank=94
# [SoftImpute] Iter 16: observed MAE=0.048684 rank=94
# [SoftImpute] Iter 17: observed MAE=0.048734 rank=94
# [SoftImpute] Iter 18: observed MAE=0.048782 rank=94
# [SoftImpute] Iter 19: observed MAE=0.048828 rank=94
# [SoftImpute] Iter 20: observed MAE=0.048872 rank=94
# [SoftImpute] Iter 21: observed MAE=0.048914 rank=94
# [SoftImpute] Iter 22: observed MAE=0.048954 rank=94
# [SoftImpute] Iter 23: observed MAE=0.048993 rank=94
# [SoftImpute] Iter 24: observed MAE=0.049030 rank=94
# [SoftImpute] Iter 25: observed MAE=0.049065 rank=94
# [SoftImpute] Iter 26: observed MAE=0.049099 rank=94
# [SoftImpute] Iter 27: observed MAE=0.049132 rank=94
# [SoftImpute] Iter 28: observed MAE=0.049163 rank=94
# [SoftImpute] Iter 29: observed MAE=0.049193 rank=94
# [SoftImpute] Iter 30: observed MAE=0.049222 rank=94
# [SoftImpute] Stopped after iteration 30 for lambda=20.829937
# 135.50139308
# [SoftImpute] Max Singular Value of X_init = 771.927642
# [SoftImpute] Iter 1: observed MAE=0.032600 rank=87
# [SoftImpute] Iter 2: observed MAE=0.032660 rank=87
# [SoftImpute] Iter 3: observed MAE=0.032717 rank=87
# [SoftImpute] Iter 4: observed MAE=0.032772 rank=87
# [SoftImpute] Iter 5: observed MAE=0.032824 rank=87
# [SoftImpute] Iter 6: observed MAE=0.032875 rank=87
# [SoftImpute] Iter 7: observed MAE=0.032924 rank=87
# [SoftImpute] Iter 8: observed MAE=0.032972 rank=87
# [SoftImpute] Iter 9: observed MAE=0.033017 rank=87
# [SoftImpute] Iter 10: observed MAE=0.033061 rank=87
# [SoftImpute] Iter 11: observed MAE=0.033104 rank=87
# [SoftImpute] Iter 12: observed MAE=0.033145 rank=87
# [SoftImpute] Iter 13: observed MAE=0.033184 rank=87
# [SoftImpute] Iter 14: observed MAE=0.033222 rank=87
# [SoftImpute] Iter 15: observed MAE=0.033259 rank=87
# [SoftImpute] Iter 16: observed MAE=0.033295 rank=87
# [SoftImpute] Iter 17: observed MAE=0.033329 rank=87
# [SoftImpute] Iter 18: observed MAE=0.033363 rank=87
# [SoftImpute] Iter 19: observed MAE=0.033395 rank=87
# [SoftImpute] Iter 20: observed MAE=0.033426 rank=87
# [SoftImpute] Iter 21: observed MAE=0.033456 rank=87
# [SoftImpute] Iter 22: observed MAE=0.033486 rank=87
# [SoftImpute] Iter 23: observed MAE=0.033514 rank=87
# [SoftImpute] Iter 24: observed MAE=0.033542 rank=87
# [SoftImpute] Iter 25: observed MAE=0.033568 rank=87
# [SoftImpute] Iter 26: observed MAE=0.033594 rank=87
# [SoftImpute] Iter 27: observed MAE=0.033619 rank=87
# [SoftImpute] Iter 28: observed MAE=0.033643 rank=87
# [SoftImpute] Iter 29: observed MAE=0.033667 rank=87
# [SoftImpute] Iter 30: observed MAE=0.033690 rank=87
# [SoftImpute] Stopped after iteration 30 for lambda=15.438553
# 90.4853980541
# predicting, mean RMSEs=0.122454
# 32
# [SoftImpute] Max Singular Value of X_init = 1019.018307
# [SoftImpute] Iter 1: observed MAE=0.053590 rank=119
# [SoftImpute] Iter 2: observed MAE=0.053819 rank=119
# [SoftImpute] Iter 3: observed MAE=0.054035 rank=119
# [SoftImpute] Iter 4: observed MAE=0.054237 rank=119
# [SoftImpute] Iter 5: observed MAE=0.054427 rank=119
# [SoftImpute] Iter 6: observed MAE=0.054606 rank=119
# [SoftImpute] Iter 7: observed MAE=0.054774 rank=119
# [SoftImpute] Iter 8: observed MAE=0.054933 rank=119
# [SoftImpute] Iter 9: observed MAE=0.055083 rank=119
# [SoftImpute] Iter 10: observed MAE=0.055225 rank=119
# [SoftImpute] Iter 11: observed MAE=0.055360 rank=119
# [SoftImpute] Iter 12: observed MAE=0.055488 rank=119
# [SoftImpute] Iter 13: observed MAE=0.055609 rank=119
# [SoftImpute] Iter 14: observed MAE=0.055725 rank=119
# [SoftImpute] Iter 15: observed MAE=0.055836 rank=119
# [SoftImpute] Iter 16: observed MAE=0.055942 rank=119
# [SoftImpute] Iter 17: observed MAE=0.056043 rank=119
# [SoftImpute] Iter 18: observed MAE=0.056139 rank=119
# [SoftImpute] Iter 19: observed MAE=0.056232 rank=119
# [SoftImpute] Iter 20: observed MAE=0.056321 rank=119
# [SoftImpute] Iter 21: observed MAE=0.056407 rank=119
# [SoftImpute] Iter 22: observed MAE=0.056489 rank=119
# [SoftImpute] Iter 23: observed MAE=0.056568 rank=119
# [SoftImpute] Iter 24: observed MAE=0.056644 rank=119
# [SoftImpute] Iter 25: observed MAE=0.056717 rank=119
# [SoftImpute] Iter 26: observed MAE=0.056788 rank=119
# [SoftImpute] Iter 27: observed MAE=0.056856 rank=119
# [SoftImpute] Iter 28: observed MAE=0.056921 rank=119
# [SoftImpute] Iter 29: observed MAE=0.056985 rank=119
# [SoftImpute] Iter 30: observed MAE=0.057046 rank=119
# [SoftImpute] Stopped after iteration 30 for lambda=20.380366
# 81.3613159657
# [SoftImpute] Max Singular Value of X_init = 932.800875
# [SoftImpute] Iter 1: observed MAE=0.047716 rank=115
# [SoftImpute] Iter 2: observed MAE=0.047898 rank=115
# [SoftImpute] Iter 3: observed MAE=0.048068 rank=115
# [SoftImpute] Iter 4: observed MAE=0.048229 rank=115
# [SoftImpute] Iter 5: observed MAE=0.048381 rank=115
# [SoftImpute] Iter 6: observed MAE=0.048524 rank=115
# [SoftImpute] Iter 7: observed MAE=0.048661 rank=115
# [SoftImpute] Iter 8: observed MAE=0.048790 rank=115
# [SoftImpute] Iter 9: observed MAE=0.048913 rank=115
# [SoftImpute] Iter 10: observed MAE=0.049031 rank=115
# [SoftImpute] Iter 11: observed MAE=0.049143 rank=115
# [SoftImpute] Iter 12: observed MAE=0.049250 rank=115
# [SoftImpute] Iter 13: observed MAE=0.049352 rank=115
# [SoftImpute] Iter 14: observed MAE=0.049450 rank=115
# [SoftImpute] Iter 15: observed MAE=0.049543 rank=115
# [SoftImpute] Iter 16: observed MAE=0.049633 rank=115
# [SoftImpute] Iter 17: observed MAE=0.049720 rank=115
# [SoftImpute] Iter 18: observed MAE=0.049802 rank=115
# [SoftImpute] Iter 19: observed MAE=0.049882 rank=115
# [SoftImpute] Iter 20: observed MAE=0.049959 rank=115
# [SoftImpute] Iter 21: observed MAE=0.050032 rank=115
# [SoftImpute] Iter 22: observed MAE=0.050103 rank=115
# [SoftImpute] Iter 23: observed MAE=0.050172 rank=115
# [SoftImpute] Iter 24: observed MAE=0.050238 rank=115
# [SoftImpute] Iter 25: observed MAE=0.050301 rank=115
# [SoftImpute] Iter 26: observed MAE=0.050363 rank=115
# [SoftImpute] Iter 27: observed MAE=0.050422 rank=115
# [SoftImpute] Iter 28: observed MAE=0.050480 rank=115
# [SoftImpute] Iter 29: observed MAE=0.050535 rank=115
# [SoftImpute] Iter 30: observed MAE=0.050589 rank=115
# [SoftImpute] Stopped after iteration 30 for lambda=18.656017
# 82.5646669865
# [SoftImpute] Max Singular Value of X_init = 969.725660
# [SoftImpute] Iter 1: observed MAE=0.052207 rank=121
# [SoftImpute] Iter 2: observed MAE=0.052405 rank=121
# [SoftImpute] Iter 3: observed MAE=0.052592 rank=121
# [SoftImpute] Iter 4: observed MAE=0.052768 rank=121
# [SoftImpute] Iter 5: observed MAE=0.052935 rank=121
# [SoftImpute] Iter 6: observed MAE=0.053092 rank=121
# [SoftImpute] Iter 7: observed MAE=0.053242 rank=121
# [SoftImpute] Iter 8: observed MAE=0.053384 rank=121
# [SoftImpute] Iter 9: observed MAE=0.053519 rank=121
# [SoftImpute] Iter 10: observed MAE=0.053647 rank=121
# [SoftImpute] Iter 11: observed MAE=0.053769 rank=121
# [SoftImpute] Iter 12: observed MAE=0.053885 rank=121
# [SoftImpute] Iter 13: observed MAE=0.053996 rank=121
# [SoftImpute] Iter 14: observed MAE=0.054103 rank=121
# [SoftImpute] Iter 15: observed MAE=0.054204 rank=121
# [SoftImpute] Iter 16: observed MAE=0.054302 rank=121
# [SoftImpute] Iter 17: observed MAE=0.054395 rank=121
# [SoftImpute] Iter 18: observed MAE=0.054485 rank=121
# [SoftImpute] Iter 19: observed MAE=0.054571 rank=121
# [SoftImpute] Iter 20: observed MAE=0.054654 rank=121
# [SoftImpute] Iter 21: observed MAE=0.054733 rank=121
# [SoftImpute] Iter 22: observed MAE=0.054810 rank=121
# [SoftImpute] Iter 23: observed MAE=0.054884 rank=121
# [SoftImpute] Iter 24: observed MAE=0.054955 rank=121
# [SoftImpute] Iter 25: observed MAE=0.055024 rank=121
# [SoftImpute] Iter 26: observed MAE=0.055090 rank=121
# [SoftImpute] Iter 27: observed MAE=0.055154 rank=121
# [SoftImpute] Iter 28: observed MAE=0.055215 rank=121
# [SoftImpute] Iter 29: observed MAE=0.055275 rank=121
# [SoftImpute] Iter 30: observed MAE=0.055333 rank=121
# [SoftImpute] Stopped after iteration 30 for lambda=19.394513
# 71.8873140812
# [SoftImpute] Max Singular Value of X_init = 1252.053467
# [SoftImpute] Iter 1: observed MAE=0.065062 rank=116
# [SoftImpute] Iter 2: observed MAE=0.065387 rank=116
# [SoftImpute] Iter 3: observed MAE=0.065688 rank=116
# [SoftImpute] Iter 4: observed MAE=0.065969 rank=116
# [SoftImpute] Iter 5: observed MAE=0.066230 rank=116
# [SoftImpute] Iter 6: observed MAE=0.066474 rank=116
# [SoftImpute] Iter 7: observed MAE=0.066701 rank=116
# [SoftImpute] Iter 8: observed MAE=0.066915 rank=116
# [SoftImpute] Iter 9: observed MAE=0.067115 rank=116
# [SoftImpute] Iter 10: observed MAE=0.067303 rank=116
# [SoftImpute] Iter 11: observed MAE=0.067481 rank=116
# [SoftImpute] Iter 12: observed MAE=0.067648 rank=116
# [SoftImpute] Iter 13: observed MAE=0.067806 rank=116
# [SoftImpute] Iter 14: observed MAE=0.067956 rank=116
# [SoftImpute] Iter 15: observed MAE=0.068098 rank=116
# [SoftImpute] Iter 16: observed MAE=0.068232 rank=116
# [SoftImpute] Iter 17: observed MAE=0.068360 rank=116
# [SoftImpute] Iter 18: observed MAE=0.068482 rank=116
# [SoftImpute] Iter 19: observed MAE=0.068598 rank=116
# [SoftImpute] Iter 20: observed MAE=0.068709 rank=116
# [SoftImpute] Iter 21: observed MAE=0.068814 rank=116
# [SoftImpute] Iter 22: observed MAE=0.068915 rank=116
# [SoftImpute] Iter 23: observed MAE=0.069012 rank=116
# [SoftImpute] Iter 24: observed MAE=0.069104 rank=116
# [SoftImpute] Iter 25: observed MAE=0.069193 rank=116
# [SoftImpute] Iter 26: observed MAE=0.069278 rank=116
# [SoftImpute] Iter 27: observed MAE=0.069360 rank=116
# [SoftImpute] Iter 28: observed MAE=0.069438 rank=116
# [SoftImpute] Iter 29: observed MAE=0.069513 rank=116
# [SoftImpute] Iter 30: observed MAE=0.069586 rank=116
# [SoftImpute] Stopped after iteration 30 for lambda=25.041069
# 78.5217041969
# [SoftImpute] Max Singular Value of X_init = 1023.061327
# [SoftImpute] Iter 1: observed MAE=0.053620 rank=117
# [SoftImpute] Iter 2: observed MAE=0.053836 rank=117
# [SoftImpute] Iter 3: observed MAE=0.054039 rank=117
# [SoftImpute] Iter 4: observed MAE=0.054230 rank=117
# [SoftImpute] Iter 5: observed MAE=0.054410 rank=117
# [SoftImpute] Iter 6: observed MAE=0.054580 rank=117
# [SoftImpute] Iter 7: observed MAE=0.054741 rank=117
# [SoftImpute] Iter 8: observed MAE=0.054893 rank=117
# [SoftImpute] Iter 9: observed MAE=0.055038 rank=117
# [SoftImpute] Iter 10: observed MAE=0.055175 rank=117
# [SoftImpute] Iter 11: observed MAE=0.055306 rank=117
# [SoftImpute] Iter 12: observed MAE=0.055430 rank=117
# [SoftImpute] Iter 13: observed MAE=0.055549 rank=117
# [SoftImpute] Iter 14: observed MAE=0.055663 rank=117
# [SoftImpute] Iter 15: observed MAE=0.055771 rank=117
# [SoftImpute] Iter 16: observed MAE=0.055875 rank=117
# [SoftImpute] Iter 17: observed MAE=0.055974 rank=117
# [SoftImpute] Iter 18: observed MAE=0.056069 rank=117
# [SoftImpute] Iter 19: observed MAE=0.056161 rank=117
# [SoftImpute] Iter 20: observed MAE=0.056249 rank=117
# [SoftImpute] Iter 21: observed MAE=0.056333 rank=117
# [SoftImpute] Iter 22: observed MAE=0.056414 rank=117
# [SoftImpute] Iter 23: observed MAE=0.056492 rank=117
# [SoftImpute] Iter 24: observed MAE=0.056568 rank=117
# [SoftImpute] Iter 25: observed MAE=0.056640 rank=117
# [SoftImpute] Iter 26: observed MAE=0.056710 rank=117
# [SoftImpute] Iter 27: observed MAE=0.056778 rank=117
# [SoftImpute] Iter 28: observed MAE=0.056843 rank=117
# [SoftImpute] Iter 29: observed MAE=0.056906 rank=117
# [SoftImpute] Iter 30: observed MAE=0.056967 rank=117
# [SoftImpute] Stopped after iteration 30 for lambda=20.461227
# 74.9296619892
# predicting, mean RMSEs=0.087943
# 64
# [SoftImpute] Max Singular Value of X_init = 1165.988112
# [SoftImpute] Iter 1: observed MAE=0.066251 rank=124
# [SoftImpute] Iter 2: observed MAE=0.066676 rank=124
# [SoftImpute] Iter 3: observed MAE=0.067071 rank=124
# [SoftImpute] Iter 4: observed MAE=0.067437 rank=124
# [SoftImpute] Iter 5: observed MAE=0.067778 rank=124
# [SoftImpute] Iter 6: observed MAE=0.068096 rank=124
# [SoftImpute] Iter 7: observed MAE=0.068394 rank=124
# [SoftImpute] Iter 8: observed MAE=0.068672 rank=124
# [SoftImpute] Iter 9: observed MAE=0.068933 rank=124
# [SoftImpute] Iter 10: observed MAE=0.069179 rank=124
# [SoftImpute] Iter 11: observed MAE=0.069410 rank=124
# [SoftImpute] Iter 12: observed MAE=0.069627 rank=124
# [SoftImpute] Iter 13: observed MAE=0.069833 rank=124
# [SoftImpute] Iter 14: observed MAE=0.070027 rank=124
# [SoftImpute] Iter 15: observed MAE=0.070211 rank=124
# [SoftImpute] Iter 16: observed MAE=0.070385 rank=124
# [SoftImpute] Iter 17: observed MAE=0.070550 rank=124
# [SoftImpute] Iter 18: observed MAE=0.070707 rank=124
# [SoftImpute] Iter 19: observed MAE=0.070855 rank=124
# [SoftImpute] Iter 20: observed MAE=0.070997 rank=124
# [SoftImpute] Iter 21: observed MAE=0.071132 rank=124
# [SoftImpute] Iter 22: observed MAE=0.071261 rank=124
# [SoftImpute] Iter 23: observed MAE=0.071384 rank=124
# [SoftImpute] Iter 24: observed MAE=0.071501 rank=124
# [SoftImpute] Iter 25: observed MAE=0.071613 rank=124
# [SoftImpute] Iter 26: observed MAE=0.071720 rank=124
# [SoftImpute] Iter 27: observed MAE=0.071823 rank=124
# [SoftImpute] Iter 28: observed MAE=0.071921 rank=124
# [SoftImpute] Iter 29: observed MAE=0.072015 rank=124
# [SoftImpute] Iter 30: observed MAE=0.072105 rank=124
# [SoftImpute] Stopped after iteration 30 for lambda=23.319762
# 40.9244110584
# [SoftImpute] Max Singular Value of X_init = 1129.720065
# [SoftImpute] Iter 1: observed MAE=0.063834 rank=124
# [SoftImpute] Iter 2: observed MAE=0.064221 rank=124
# [SoftImpute] Iter 3: observed MAE=0.064583 rank=124
# [SoftImpute] Iter 4: observed MAE=0.064922 rank=124
# [SoftImpute] Iter 5: observed MAE=0.065239 rank=124
# [SoftImpute] Iter 6: observed MAE=0.065537 rank=124
# [SoftImpute] Iter 7: observed MAE=0.065817 rank=124
# [SoftImpute] Iter 8: observed MAE=0.066080 rank=124
# [SoftImpute] Iter 9: observed MAE=0.066328 rank=124
# [SoftImpute] Iter 10: observed MAE=0.066562 rank=124
# [SoftImpute] Iter 11: observed MAE=0.066783 rank=124
# [SoftImpute] Iter 12: observed MAE=0.066992 rank=124
# [SoftImpute] Iter 13: observed MAE=0.067190 rank=124
